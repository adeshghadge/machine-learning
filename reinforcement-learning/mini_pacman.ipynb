# %%
import numpy as np
import random
import time
import os
import gc

from keras.models import Sequential, clone_model
from keras.layers import Dense, Flatten, Conv2D, InputLayer
from keras.callbacks import CSVLogger, TensorBoard, EarlyStopping
from keras.optimizers import Adam
import keras.backend as K

import gym
from collections import deque
from mini_pacman import PacmanGame, test
import itertools

# %%
def get_state(obs):
    v = []
    x,y = obs['player']
    v.append(x)
    v.append(y)
    for x, y in obs['monsters']:
        v.append(x)
        v.append(y)
    for x, y in obs['diamonds']:
        v.append(x)
        v.append(y)
    for x, y in obs['walls']:
        v.append(x)
        v.append(y)
    return v

# %%
def create_dqn_model(input_shape, nb_actions, dense_layers, dense_units):
    model = Sequential()
    model.add(InputLayer(input_shape=input_shape))
    for i in range(dense_layers):
        model.add(Dense(units=dense_units, activation='relu'))
    model.add(Dense(nb_actions, activation='linear'))
    return model

# %%
def epsilon_greedy(q_values, epsilon, n_outputs):
    if random.random() < epsilon:
        return random.randrange(1, n_outputs, 1)  # random action
    else:
        return 1+np.argmax(q_values)          # q-optimal action

# %%
#env = gym.make("MsPacman-ram-v0")                                                                                                                                                                                                                                              
env = PacmanGame(field_shape=(8, 8), nmonsters=2, ndiamonds=3, nwalls=10, monster_vision_range=2) #, max_moves=100, diamond_reward=100, survival_reward=1)                                                                                                                      
#env = PacmanGame(field_shape=(10,10), nmonsters=2,ndiamonds=3, nwalls=4, monster_vision_range=1)                                                                                                                                                                               
obs = env.reset()
end_game = False
score = 0


input_shape = (32,) #obs.shape                                                                                                                                                                                                                                                  
nb_actions = 9 #env.action_space.n  # 9                                                                                                                                                                                                                                         
dense_layers = 5
dense_units = 256

online_network = create_dqn_model(input_shape, nb_actions, dense_layers, dense_units)


replay_memory_maxlen = 1000000
replay_memory = deque([], maxlen=replay_memory_maxlen)


target_network = clone_model(online_network)
target_network.set_weights(online_network.get_weights())

# %%
def mean_q(y_true, y_pred):
    return K.mean(K.max(y_pred, axis=-1))

# %%
name = 'MiniPacman_DQN'  # used in naming files (weights, logs, etc)                                                                                                                                                                                                            
n_steps = 5000        # total number of training steps (= n_epochs)                                                                                                                                                                                                            
warmup = 1000          # start training after warmup iterations                                                                                                                                                                                                                 
training_interval = 4  # period (in actions) between training steps                                                                                                                                                                                                             
save_steps = int(n_steps/10)  # period (in training steps) between storing weights to file                                                                                                                                                                                      
copy_steps = 100       # period (in training steps) between updating target_network weights                                                                                                                                                                                     
gamma = 0.95            # discount rate                                                                                                                                                                                                                                          
skip_start = 10        # skip the start of every game (it's just freezing time before game starts)                                                                                                                                                                              
batch_size = 64        # size of minibatch that is taken randomly from replay memory every training step                                                                                                                                                                        
double_dqn = False     # whether to use Double-DQN approach or simple DQN (see above)                                                                                                                                                                                           
# eps-greedy parameters: we slowly decrease epsilon from eps_max to eps_min in eps_decay_steps                                                                                                                                                                                  
eps_max = 1.0
eps_min = 0.05
eps_decay_steps = int(n_steps/2)

learning_rate = 0.0001

# %%
online_network.compile(optimizer=Adam(learning_rate), loss='mse', metrics=[mean_q])

if not os.path.exists(name):
    os.makedirs(name)

weights_folder = os.path.join(name, 'weights')
if not os.path.exists(weights_folder):
    os.makedirs(weights_folder)


csv_logger = CSVLogger(os.path.join(name, 'log.csv'), append=True, separator=';')
early_stopping = EarlyStopping(monitor='mean_q', patience=300)





# counters:                                                                                                                                                                                                                                                                     
step = 0          # training step counter (= epoch counter)                                                                                                                                                                                                                     
iteration = 0     # frames counter                                                                                                                                                                                                                                              
episodes = 0      # game episodes counter                                                                                                                                                                                                                                       
end_game = True       # indicator that env needs to be reset                                                                                                                                                                                                                    

episode_scores = []  # collect total scores in this list and log it later                                                                                                                                                                                                       


while step < n_steps:
    if end_game:  # game over, restart it                                                                                                                                                                                                                                       
        obs = env.reset()
        score = 0  # reset score for current episode                                                                                                                                                                                                                            
        #for skip in range(skip_start):  # skip the start of each game (it's just freezing time before game starts)                                                                                                                                                              
        #    try:
        #        obs = env.make_action(1) #env.step(0)                                                                                                                                                                                                                           
        #        reward = obs['reward']
        #        end_game = obs['end_game']
        #        score += reward
        #    except AssertionError:
        #        continue

        state = get_state(obs)
        episodes += 1

    # Online network evaluates what to do                                                                                                                                                                                                                                       
    iteration += 1
    q_values = online_network.predict(np.array([state]))[0]  # calculate q-values using online network                                                                                                                                                                          

    # select epsilon (which linearly decreases over training steps):                                                                                                                                                                                                            
    epsilon = max(eps_min, eps_max - (eps_max-eps_min) * step/eps_decay_steps)
    action = epsilon_greedy(q_values, epsilon, nb_actions)

    # Play:                                                                                                                                                                                                                                                                     
    try:
        obs = env.make_action(action)
        reward = obs['reward']
        end_game = obs['end_game']
    except AssertionError:
        continue

    score += reward

    if end_game:
        episode_scores.append(score)
    next_state = get_state(obs)
    # Let's memorize what just happened                                                                                                                                                                                                                                         
    replay_memory.append((state, action, reward, next_state, end_game))
    state = next_state

    if iteration >= warmup and iteration % training_interval == 0:
        # learning branch                                                                                                                                                                                                                                                       
        step += 1

        #minibatch = random.sample(replay_memory, batch_size)                                                                                                                                                                                                                   
        minibatch = []
        selectcnt = 4
        batch_counter = 0
        batch_limit = batch_size/selectcnt
        batch_selection_complete = False
        batch_indices = []

        while(not batch_selection_complete):
            cstart = random.randint(0, len(replay_memory) - selectcnt)

            if(any(ind in batch_indices for ind in (cstart, cstart+1, cstart+2, cstart+3))):
                continue

            batch_indices.append(cstart)

            minibatch = (minibatch + (list(itertools.islice(replay_memory, cstart, cstart + selectcnt))))

            batch_counter += 1

            if(batch_counter == batch_limit):
                batch_selection_complete = True

        replay_state = np.array([x[0] for x in minibatch])
        replay_action = np.array([x[1] for x in minibatch])
        replay_rewards = np.array([x[2] for x in minibatch])
        replay_next_state = np.array([x[3] for x in minibatch])
        replay_end_game = np.array([x[4] for x in minibatch], dtype=int)

        # calculate targets (see above for details)                                                                                                                                                                                                                             
        if double_dqn == False:
            # DQN                                                                                                                                                                                                                                                               
            target_for_action = replay_rewards + (1-replay_end_game) * gamma * \
                                    np.amax(target_network.predict(replay_next_state), axis=1)
        else:
            # Double DQN                                                                                                                                                                                                                                                        
            best_actions = np.argmax(online_network.predict(replay_next_state), axis=1)
            target_for_action = replay_rewards + (1-replay_end_game) * gamma * \
                                    target_network.predict(replay_next_state)[np.arange(batch_size), best_actions-1]
            
        target = online_network.predict(replay_state)  # targets coincide with predictions ...                                                                                                                                                                                  
        target[np.arange(batch_size), replay_action-1] = target_for_action  #...except for targets with actions from replay                                                                                                                                                       

        # Train online network                                                                                                                                                                                                                                                  
        online_network.fit(replay_state, target, epochs=step, verbose=2, initial_epoch=step-1,
                           callbacks=[early_stopping])

        # Periodically copy online network weights to target network                                                                                                                                                                                                            
        if step % copy_steps == 0:
            target_network.set_weights(online_network.get_weights())
        # And save weights                                                                                                                                                                                                                                                      
        if step % save_steps == 0:
            online_network.save_weights(os.path.join(weights_folder, 'weights_{}.h5f'.format(step)))
            gc.collect()  # also clean the garbage
# Out:
# Epoch 1/1
#  - 1s - loss: 0.5120 - mean_q: 0.8490
# Epoch 2/2
#  - 0s - loss: 0.1647 - mean_q: 0.8648
# Epoch 3/3
#  - 0s - loss: 0.3589 - mean_q: 0.9551
# Epoch 4/4
#  - 0s - loss: 0.1424 - mean_q: 1.0911
# Epoch 5/5
#  - 0s - loss: 0.3175 - mean_q: 1.1760
# Epoch 6/6
#  - 0s - loss: 0.2934 - mean_q: 1.2155
# Epoch 7/7
#  - 0s - loss: 0.3433 - mean_q: 1.3264
# Epoch 8/8
#  - 0s - loss: 0.0563 - mean_q: 1.4284
# Epoch 9/9
#  - 0s - loss: 0.0573 - mean_q: 1.4627
# Epoch 10/10
#  - 0s - loss: 0.2074 - mean_q: 1.6626
# Epoch 11/11
#  - 0s - loss: 0.2000 - mean_q: 1.7569
# Epoch 12/12
#  - 0s - loss: 0.1956 - mean_q: 1.8000
# Epoch 13/13
#  - 0s - loss: 0.1725 - mean_q: 1.8271
# Epoch 14/14
#  - 0s - loss: 0.0505 - mean_q: 1.9096
# Epoch 15/15
#  - 0s - loss: 0.2208 - mean_q: 1.9786
# Epoch 16/16
#  - 0s - loss: 0.0252 - mean_q: 1.9387
# Epoch 17/17
#  - 0s - loss: 0.2100 - mean_q: 2.0550
# Epoch 18/18
#  - 0s - loss: 0.0358 - mean_q: 1.8550
# Epoch 19/19
#  - 0s - loss: 0.2001 - mean_q: 1.9049
# Epoch 20/20
#  - 0s - loss: 0.3421 - mean_q: 1.9214
# Epoch 21/21
#  - 0s - loss: 0.5351 - mean_q: 2.0056
# Epoch 22/22
#  - 0s - loss: 0.0457 - mean_q: 2.0586
# Epoch 23/23
#  - 0s - loss: 0.2383 - mean_q: 2.1145
# Epoch 24/24
#  - 0s - loss: 0.0408 - mean_q: 2.0256
# Epoch 25/25
#  - 0s - loss: 0.0269 - mean_q: 1.9954
# Epoch 26/26
#  - 0s - loss: 0.0251 - mean_q: 1.9774
# Epoch 27/27
#  - 0s - loss: 0.2104 - mean_q: 1.9432
# Epoch 28/28
#  - 0s - loss: 0.2033 - mean_q: 1.8863
# Epoch 29/29
#  - 0s - loss: 0.0167 - mean_q: 1.9096
# Epoch 30/30
#  - 0s - loss: 0.3837 - mean_q: 1.9459
# Epoch 31/31
#  - 0s - loss: 0.3660 - mean_q: 1.8643
# Epoch 32/32
#  - 0s - loss: 0.0167 - mean_q: 1.9067
# Epoch 33/33
#  - 0s - loss: 0.0309 - mean_q: 2.0432
# Epoch 34/34
#  - 0s - loss: 0.3577 - mean_q: 1.9918
# Epoch 35/35
#  - 0s - loss: 0.1982 - mean_q: 1.9847
# Epoch 36/36
#  - 0s - loss: 0.3474 - mean_q: 2.1553
# Epoch 37/37
#  - 0s - loss: 0.3796 - mean_q: 2.0782
# Epoch 38/38
#  - 0s - loss: 0.3013 - mean_q: 2.0638
# Epoch 39/39
#  - 0s - loss: 0.0392 - mean_q: 2.0688
# Epoch 40/40
#  - 0s - loss: 0.4792 - mean_q: 2.0905
# Epoch 41/41
#  - 0s - loss: 0.0371 - mean_q: 2.1159
# Epoch 42/42
#  - 0s - loss: 0.2885 - mean_q: 2.1520
# Epoch 43/43
#  - 0s - loss: 0.1911 - mean_q: 2.2096
# Epoch 44/44
#  - 0s - loss: 0.3503 - mean_q: 2.2907
# Epoch 45/45
#  - 0s - loss: 0.1906 - mean_q: 2.1549
# Epoch 46/46
#  - 0s - loss: 0.0403 - mean_q: 2.1424
# Epoch 47/47
#  - 0s - loss: 0.1947 - mean_q: 2.1265
# Epoch 48/48
#  - 0s - loss: 0.2203 - mean_q: 2.1023
# Epoch 49/49
#  - 0s - loss: 0.2052 - mean_q: 2.0363
# Epoch 50/50
#  - 0s - loss: 0.0190 - mean_q: 2.0626
# Epoch 51/51
#  - 0s - loss: 0.2324 - mean_q: 1.9429
# Epoch 52/52
#  - 0s - loss: 0.5603 - mean_q: 1.9054
# Epoch 53/53
#  - 0s - loss: 0.1838 - mean_q: 2.0232
# Epoch 54/54
#  - 0s - loss: 0.1841 - mean_q: 2.0080
# Epoch 55/55
#  - 0s - loss: 0.4713 - mean_q: 2.1127
# Epoch 56/56
#  - 0s - loss: 0.1765 - mean_q: 2.0989
# Epoch 57/57
#  - 0s - loss: 0.2152 - mean_q: 2.2067
# Epoch 58/58
#  - 0s - loss: 0.0228 - mean_q: 2.2415
# Epoch 59/59
#  - 0s - loss: 0.0284 - mean_q: 2.2557
# Epoch 60/60
#  - 0s - loss: 0.1979 - mean_q: 2.0890
# Epoch 61/61
#  - 0s - loss: 0.0429 - mean_q: 2.1483
# Epoch 62/62
#  - 0s - loss: 0.3778 - mean_q: 1.9524
# Epoch 63/63
#  - 0s - loss: 0.5448 - mean_q: 2.0273
# Epoch 64/64
#  - 0s - loss: 0.0105 - mean_q: 2.0794
# Epoch 65/65
#  - 0s - loss: 0.1879 - mean_q: 2.1157
# Epoch 66/66
#  - 0s - loss: 0.3464 - mean_q: 2.0534
# Epoch 67/67
#  - 0s - loss: 0.3493 - mean_q: 2.2264
# Epoch 68/68
#  - 0s - loss: 0.1301 - mean_q: 2.1819
# Epoch 69/69
#  - 0s - loss: 0.3476 - mean_q: 2.2457
# Epoch 70/70
#  - 0s - loss: 0.2066 - mean_q: 2.3952
# Epoch 71/71
#  - 0s - loss: 0.2073 - mean_q: 2.3286
# Epoch 72/72
#  - 0s - loss: 0.1620 - mean_q: 2.3020
# Epoch 73/73
#  - 0s - loss: 0.2183 - mean_q: 2.3977
# Epoch 74/74
#  - 0s - loss: 0.0437 - mean_q: 2.3696
# Epoch 75/75
#  - 0s - loss: 0.0164 - mean_q: 2.1641
# Epoch 76/76
#  - 0s - loss: 0.1732 - mean_q: 2.2893
# Epoch 77/77
#  - 0s - loss: 0.1120 - mean_q: 2.3158
# Epoch 78/78
#  - 0s - loss: 0.0389 - mean_q: 2.1583
# Epoch 79/79
#  - 0s - loss: 0.1768 - mean_q: 2.0011
# Epoch 80/80
#  - 0s - loss: 0.4989 - mean_q: 2.1754
# Epoch 81/81
#  - 0s - loss: 0.0276 - mean_q: 2.1369
# Epoch 82/82
#  - 0s - loss: 0.1607 - mean_q: 2.2362
# Epoch 83/83
#  - 0s - loss: 0.1677 - mean_q: 2.2959
# Epoch 84/84
#  - 0s - loss: 0.1978 - mean_q: 2.2295
# Epoch 85/85
#  - 0s - loss: 0.2152 - mean_q: 2.2491
# Epoch 86/86
#  - 0s - loss: 0.2115 - mean_q: 2.1874
# Epoch 87/87
#  - 0s - loss: 0.3141 - mean_q: 2.3798
# Epoch 88/88
#  - 0s - loss: 0.1765 - mean_q: 2.3869
# Epoch 89/89
#  - 0s - loss: 0.5349 - mean_q: 2.2078
# Epoch 90/90
#  - 0s - loss: 0.1704 - mean_q: 2.2996
# Epoch 91/91
#  - 0s - loss: 0.0332 - mean_q: 2.3002
# Epoch 92/92
#  - 0s - loss: 0.0219 - mean_q: 2.3522
# Epoch 93/93
#  - 0s - loss: 0.0457 - mean_q: 2.1829
# Epoch 94/94
#  - 0s - loss: 0.0247 - mean_q: 2.1734
# Epoch 95/95
#  - 0s - loss: 0.2962 - mean_q: 2.0528
# Epoch 96/96
#  - 0s - loss: 0.3197 - mean_q: 2.2288
# Epoch 97/97
#  - 0s - loss: 0.3638 - mean_q: 2.2106
# Epoch 98/98
#  - 0s - loss: 0.1789 - mean_q: 2.2222
# Epoch 99/99
#  - 0s - loss: 0.2309 - mean_q: 2.2877
# Epoch 100/100
#  - 0s - loss: 0.0256 - mean_q: 2.1003
# Epoch 101/101
#  - 0s - loss: 0.3992 - mean_q: 2.0932
# Epoch 102/102
#  - 0s - loss: 0.3423 - mean_q: 2.1837
# Epoch 103/103
#  - 0s - loss: 0.3408 - mean_q: 2.4196
# Epoch 104/104
#  - 0s - loss: 0.1117 - mean_q: 2.5621
# Epoch 105/105
#  - 0s - loss: 0.1082 - mean_q: 2.8397
# Epoch 106/106
#  - 0s - loss: 0.0671 - mean_q: 3.0561
# Epoch 107/107
#  - 0s - loss: 0.2894 - mean_q: 3.0500
# Epoch 108/108
#  - 0s - loss: 0.4377 - mean_q: 3.2446
# Epoch 109/109
#  - 0s - loss: 0.2367 - mean_q: 3.2682
# Epoch 110/110
#  - 0s - loss: 0.3646 - mean_q: 3.2526
# Epoch 111/111
#  - 0s - loss: 0.2277 - mean_q: 3.4147
# Epoch 112/112
#  - 0s - loss: 0.0545 - mean_q: 3.5344
# Epoch 113/113
#  - 0s - loss: 0.0360 - mean_q: 3.7068
# Epoch 114/114
#  - 0s - loss: 0.1518 - mean_q: 3.3663
# Epoch 115/115
#  - 0s - loss: 0.0286 - mean_q: 3.4755
# Epoch 116/116
#  - 0s - loss: 0.2019 - mean_q: 3.5242
# Epoch 117/117
#  - 0s - loss: 0.4114 - mean_q: 3.3778
# Epoch 118/118
#  - 0s - loss: 0.4515 - mean_q: 3.1865
# Epoch 119/119
#  - 0s - loss: 0.3043 - mean_q: 3.3594
# Epoch 120/120
#  - 0s - loss: 0.2202 - mean_q: 3.3010
# Epoch 121/121
#  - 0s - loss: 0.5465 - mean_q: 3.5405
# Epoch 122/122
#  - 0s - loss: 0.2389 - mean_q: 3.5207
# Epoch 123/123
#  - 0s - loss: 0.4259 - mean_q: 3.7054
# Epoch 124/124
#  - 0s - loss: 0.0899 - mean_q: 3.4528
# Epoch 125/125
#  - 0s - loss: 0.2074 - mean_q: 3.5770
# Epoch 126/126
#  - 0s - loss: 0.4538 - mean_q: 3.3994
# Epoch 127/127
#  - 0s - loss: 0.0638 - mean_q: 3.3996
# Epoch 128/128
#  - 0s - loss: 0.1317 - mean_q: 3.3334
# Epoch 129/129
#  - 0s - loss: 0.4256 - mean_q: 3.1302
# Epoch 130/130
#  - 0s - loss: 0.3995 - mean_q: 3.2295
# Epoch 131/131
#  - 0s - loss: 0.3725 - mean_q: 3.3261
# Epoch 132/132
#  - 0s - loss: 0.5021 - mean_q: 3.2798
# Epoch 133/133
#  - 0s - loss: 0.2656 - mean_q: 3.6362
# Epoch 134/134
#  - 0s - loss: 0.2947 - mean_q: 3.5069
# Epoch 135/135
#  - 0s - loss: 0.2494 - mean_q: 3.4123
# Epoch 136/136
#  - 0s - loss: 0.3752 - mean_q: 3.5307
# Epoch 137/137
#  - 0s - loss: 0.5700 - mean_q: 3.5069
# Epoch 138/138
#  - 0s - loss: 0.0507 - mean_q: 3.5612
# Epoch 139/139
#  - 0s - loss: 0.2789 - mean_q: 3.5089
# Epoch 140/140
#  - 0s - loss: 0.2049 - mean_q: 3.4026
# Epoch 141/141
#  - 0s - loss: 0.0432 - mean_q: 3.6531
# Epoch 142/142
#  - 0s - loss: 0.3930 - mean_q: 3.4631
# Epoch 143/143
#  - 0s - loss: 0.2389 - mean_q: 3.4686
# Epoch 144/144
#  - 0s - loss: 0.0981 - mean_q: 3.5281
# Epoch 145/145
#  - 0s - loss: 0.1176 - mean_q: 3.5252
# Epoch 146/146
#  - 0s - loss: 0.2184 - mean_q: 3.4207
# Epoch 147/147
#  - 0s - loss: 0.4181 - mean_q: 3.5417
# Epoch 148/148
#  - 0s - loss: 0.8072 - mean_q: 3.7039
# Epoch 149/149
#  - 0s - loss: 0.2220 - mean_q: 3.8185
# Epoch 150/150
#  - 0s - loss: 0.2336 - mean_q: 3.6874
# Epoch 151/151
#  - 0s - loss: 0.3997 - mean_q: 4.0134
# Epoch 152/152
#  - 0s - loss: 0.1846 - mean_q: 3.7160
# Epoch 153/153
#  - 0s - loss: 0.6557 - mean_q: 3.6825
# Epoch 154/154
#  - 0s - loss: 0.1844 - mean_q: 3.6406
# Epoch 155/155
#  - 0s - loss: 0.1998 - mean_q: 3.7156
# Epoch 156/156
#  - 0s - loss: 0.3848 - mean_q: 3.9176
# Epoch 157/157
#  - 0s - loss: 0.0604 - mean_q: 3.7172
# Epoch 158/158
#  - 0s - loss: 0.2746 - mean_q: 3.6168
# Epoch 159/159
#  - 0s - loss: 0.4166 - mean_q: 3.7592
# Epoch 160/160
#  - 0s - loss: 0.1466 - mean_q: 3.2682
# Epoch 161/161
#  - 0s - loss: 0.2506 - mean_q: 3.3603
# Epoch 162/162
#  - 0s - loss: 0.1966 - mean_q: 3.6907
# Epoch 163/163
#  - 0s - loss: 0.6385 - mean_q: 3.4695
# Epoch 164/164
#  - 0s - loss: 0.0156 - mean_q: 3.4996
# Epoch 165/165
#  - 0s - loss: 0.2908 - mean_q: 3.6058
# Epoch 166/166
#  - 0s - loss: 0.2847 - mean_q: 3.4818
# Epoch 167/167
#  - 0s - loss: 0.3688 - mean_q: 3.7433
# Epoch 168/168
#  - 0s - loss: 0.5380 - mean_q: 3.5485
# Epoch 169/169
#  - 0s - loss: 0.4765 - mean_q: 3.6919
# Epoch 170/170
#  - 0s - loss: 0.3572 - mean_q: 3.6525
# Epoch 171/171
#  - 0s - loss: 0.0593 - mean_q: 3.6144
# Epoch 172/172
#  - 0s - loss: 0.3364 - mean_q: 3.6668
# Epoch 173/173
#  - 0s - loss: 0.2694 - mean_q: 3.7251
# Epoch 174/174
#  - 0s - loss: 0.3522 - mean_q: 3.5841
# Epoch 175/175
#  - 0s - loss: 0.4829 - mean_q: 3.4111
# Epoch 176/176
#  - 0s - loss: 0.2440 - mean_q: 3.2493
# Epoch 177/177
#  - 0s - loss: 0.3146 - mean_q: 3.6008
# Epoch 178/178
#  - 0s - loss: 0.4283 - mean_q: 3.4549
# Epoch 179/179
#  - 0s - loss: 0.4780 - mean_q: 3.3831
# Epoch 180/180
#  - 0s - loss: 0.3244 - mean_q: 3.7622
# Epoch 181/181
#  - 0s - loss: 0.2791 - mean_q: 3.5779
# Epoch 182/182
#  - 0s - loss: 0.0631 - mean_q: 3.7098
# Epoch 183/183
#  - 0s - loss: 0.1985 - mean_q: 3.6655
# Epoch 184/184
#  - 0s - loss: 0.0738 - mean_q: 3.5707
# Epoch 185/185
#  - 0s - loss: 0.0445 - mean_q: 3.3751
# Epoch 186/186
#  - 0s - loss: 0.1688 - mean_q: 3.5037
# Epoch 187/187
#  - 0s - loss: 0.2170 - mean_q: 3.5298
# Epoch 188/188
#  - 0s - loss: 0.1595 - mean_q: 3.4686
# Epoch 189/189
#  - 0s - loss: 0.4163 - mean_q: 3.6318
# Epoch 190/190
#  - 0s - loss: 0.6981 - mean_q: 3.5143
# Epoch 191/191
#  - 0s - loss: 0.1122 - mean_q: 3.4005
# Epoch 192/192
#  - 0s - loss: 0.3909 - mean_q: 3.6076
# Epoch 193/193
#  - 0s - loss: 0.3122 - mean_q: 3.6070
# Epoch 194/194
#  - 0s - loss: 0.1219 - mean_q: 3.6444
# Epoch 195/195
#  - 0s - loss: 0.1586 - mean_q: 3.5462
# Epoch 196/196
#  - 0s - loss: 0.2113 - mean_q: 3.4436
# Epoch 197/197
#  - 0s - loss: 0.0811 - mean_q: 3.3599
# Epoch 198/198
#  - 0s - loss: 0.2343 - mean_q: 3.4043
# Epoch 199/199
#  - 0s - loss: 0.0680 - mean_q: 3.4447
# Epoch 200/200
#  - 0s - loss: 0.1631 - mean_q: 3.5485
# Epoch 201/201
#  - 0s - loss: 0.4838 - mean_q: 3.7009
# Epoch 202/202
#  - 0s - loss: 0.1732 - mean_q: 3.5033
# Epoch 203/203
#  - 0s - loss: 0.1384 - mean_q: 3.8488
# Epoch 204/204
#  - 0s - loss: 0.3994 - mean_q: 4.5291
# Epoch 205/205
#  - 0s - loss: 0.1427 - mean_q: 4.3911
# Epoch 206/206
#  - 0s - loss: 0.4832 - mean_q: 4.6236
# Epoch 207/207
#  - 0s - loss: 0.4005 - mean_q: 4.7347
# Epoch 208/208
#  - 0s - loss: 0.0902 - mean_q: 4.9951
# Epoch 209/209
#  - 0s - loss: 0.6496 - mean_q: 4.7997
# Epoch 210/210
#  - 0s - loss: 0.3646 - mean_q: 4.6972
# Epoch 211/211
#  - 0s - loss: 0.2573 - mean_q: 4.7566
# Epoch 212/212
#  - 0s - loss: 0.1098 - mean_q: 4.6111
# Epoch 213/213
#  - 0s - loss: 0.2587 - mean_q: 4.7333
# Epoch 214/214
#  - 0s - loss: 0.4673 - mean_q: 4.6041
# Epoch 215/215
#  - 0s - loss: 0.4423 - mean_q: 4.6213
# Epoch 216/216
#  - 0s - loss: 0.1260 - mean_q: 4.7031
# Epoch 217/217
#  - 0s - loss: 0.1670 - mean_q: 4.7484
# Epoch 218/218
#  - 0s - loss: 0.2615 - mean_q: 4.8444
# Epoch 219/219
#  - 0s - loss: 0.1677 - mean_q: 4.5777
# Epoch 220/220
#  - 0s - loss: 0.3977 - mean_q: 4.5175
# Epoch 221/221
#  - 0s - loss: 0.5957 - mean_q: 4.6197
# Epoch 222/222
#  - 0s - loss: 0.1491 - mean_q: 4.6408
# Epoch 223/223
#  - 0s - loss: 0.3517 - mean_q: 4.7134
# Epoch 224/224
#  - 0s - loss: 0.1613 - mean_q: 4.6612
# Epoch 225/225
#  - 0s - loss: 0.2573 - mean_q: 4.8077
# Epoch 226/226
#  - 0s - loss: 0.3410 - mean_q: 4.9837
# Epoch 227/227
#  - 0s - loss: 0.1232 - mean_q: 4.8267
# Epoch 228/228
#  - 0s - loss: 0.1650 - mean_q: 4.9912
# Epoch 229/229
#  - 0s - loss: 0.2960 - mean_q: 5.0257
# Epoch 230/230
#  - 0s - loss: 0.4745 - mean_q: 4.9428
# Epoch 231/231
#  - 0s - loss: 0.5122 - mean_q: 4.5442
# Epoch 232/232
#  - 0s - loss: 0.1077 - mean_q: 4.7951
# Epoch 233/233
#  - 0s - loss: 0.2190 - mean_q: 4.7978
# Epoch 234/234
#  - 0s - loss: 0.0944 - mean_q: 4.4357
# Epoch 235/235
#  - 0s - loss: 0.4181 - mean_q: 4.6161
# Epoch 236/236
#  - 0s - loss: 0.1219 - mean_q: 4.6416
# Epoch 237/237
#  - 0s - loss: 0.0531 - mean_q: 4.7422
# Epoch 238/238
#  - 0s - loss: 0.2267 - mean_q: 4.6559
# Epoch 239/239
#  - 0s - loss: 0.4247 - mean_q: 4.7665
# Epoch 240/240
#  - 0s - loss: 0.1031 - mean_q: 4.5697
# Epoch 241/241
#  - 0s - loss: 0.2859 - mean_q: 4.6848
# Epoch 242/242
#  - 0s - loss: 0.4874 - mean_q: 4.6936
# Epoch 243/243
#  - 0s - loss: 0.1280 - mean_q: 4.6684
# Epoch 244/244
#  - 0s - loss: 0.6644 - mean_q: 4.6933
# Epoch 245/245
#  - 0s - loss: 0.3284 - mean_q: 4.8782
# Epoch 246/246
#  - 0s - loss: 0.2984 - mean_q: 4.7072
# Epoch 247/247
#  - 0s - loss: 0.3600 - mean_q: 5.0814
# Epoch 248/248
#  - 0s - loss: 0.5577 - mean_q: 4.6964
# Epoch 249/249
#  - 0s - loss: 0.5994 - mean_q: 4.8712
# Epoch 250/250
#  - 0s - loss: 0.4106 - mean_q: 4.8353
# Epoch 251/251
#  - 0s - loss: 0.2166 - mean_q: 4.7603
# Epoch 252/252
#  - 0s - loss: 0.0577 - mean_q: 4.8728
# Epoch 253/253
#  - 0s - loss: 0.3419 - mean_q: 4.8078
# Epoch 254/254
#  - 0s - loss: 0.1897 - mean_q: 4.5643
# Epoch 255/255
#  - 0s - loss: 0.1527 - mean_q: 4.8191
# Epoch 256/256
#  - 0s - loss: 0.0681 - mean_q: 4.7278
# Epoch 257/257
#  - 0s - loss: 0.2245 - mean_q: 4.8491
# Epoch 258/258
#  - 0s - loss: 0.5029 - mean_q: 4.8351
# Epoch 259/259
#  - 0s - loss: 0.1370 - mean_q: 4.4193
# Epoch 260/260
#  - 0s - loss: 0.4042 - mean_q: 4.6989
# Epoch 261/261
#  - 0s - loss: 0.2184 - mean_q: 4.5965
# Epoch 262/262
#  - 0s - loss: 0.4348 - mean_q: 4.7130
# Epoch 263/263
#  - 0s - loss: 0.1092 - mean_q: 4.5677
# Epoch 264/264
#  - 0s - loss: 0.3823 - mean_q: 4.6362
# Epoch 265/265
#  - 0s - loss: 0.1063 - mean_q: 4.5464
# Epoch 266/266
#  - 0s - loss: 0.4104 - mean_q: 4.9662
# Epoch 267/267
#  - 0s - loss: 0.2926 - mean_q: 4.7733
# Epoch 268/268
#  - 0s - loss: 0.2150 - mean_q: 4.7901
# Epoch 269/269
#  - 0s - loss: 0.5596 - mean_q: 4.8490
# Epoch 270/270
#  - 0s - loss: 0.1496 - mean_q: 4.7230
# Epoch 271/271
#  - 0s - loss: 0.6501 - mean_q: 4.9557
# Epoch 272/272
#  - 0s - loss: 0.3201 - mean_q: 4.7745
# Epoch 273/273
#  - 0s - loss: 0.0914 - mean_q: 5.0503
# Epoch 274/274
#  - 0s - loss: 0.3775 - mean_q: 4.9047
# Epoch 275/275
#  - 0s - loss: 0.4122 - mean_q: 5.0073
# Epoch 276/276
#  - 0s - loss: 0.2374 - mean_q: 4.8338
# Epoch 277/277
#  - 0s - loss: 0.2103 - mean_q: 4.9619
# Epoch 278/278
#  - 0s - loss: 0.1402 - mean_q: 5.0267
# Epoch 279/279
#  - 0s - loss: 0.1027 - mean_q: 4.7084
# Epoch 280/280
#  - 0s - loss: 0.2793 - mean_q: 4.9347
# Epoch 281/281
#  - 0s - loss: 0.2596 - mean_q: 4.6061
# Epoch 282/282
#  - 0s - loss: 0.2424 - mean_q: 4.8452
# Epoch 283/283
#  - 0s - loss: 0.2727 - mean_q: 4.6634
# Epoch 284/284
#  - 0s - loss: 0.0748 - mean_q: 4.7693
# Epoch 285/285
#  - 0s - loss: 0.3184 - mean_q: 4.6180
# Epoch 286/286
#  - 0s - loss: 0.7022 - mean_q: 4.9195
# Epoch 287/287
#  - 0s - loss: 0.1729 - mean_q: 4.9059
# Epoch 288/288
#  - 0s - loss: 0.1394 - mean_q: 5.0076
# Epoch 289/289
#  - 0s - loss: 0.4946 - mean_q: 4.8679
# Epoch 290/290
#  - 0s - loss: 0.5484 - mean_q: 4.8713
# Epoch 291/291
#  - 0s - loss: 0.1609 - mean_q: 4.9405
# Epoch 292/292
#  - 0s - loss: 0.3763 - mean_q: 5.1418
# Epoch 293/293
#  - 0s - loss: 0.1750 - mean_q: 4.9117
# Epoch 294/294
#  - 0s - loss: 0.2183 - mean_q: 4.8995
# Epoch 295/295
#  - 0s - loss: 0.0737 - mean_q: 4.8739
# Epoch 296/296
#  - 0s - loss: 0.1555 - mean_q: 4.7241
# Epoch 297/297
#  - 0s - loss: 0.1029 - mean_q: 4.7178
# Epoch 298/298
#  - 0s - loss: 0.6738 - mean_q: 5.0119
# Epoch 299/299
#  - 0s - loss: 0.5455 - mean_q: 5.0046
# Epoch 300/300
#  - 0s - loss: 0.1502 - mean_q: 5.2567
# Epoch 301/301
#  - 0s - loss: 0.4358 - mean_q: 4.8955
# Epoch 302/302
#  - 0s - loss: 0.4657 - mean_q: 5.1221
# Epoch 303/303
#  - 0s - loss: 0.3075 - mean_q: 5.2940
# Epoch 304/304
#  - 0s - loss: 0.1897 - mean_q: 5.6347
# Epoch 305/305
#  - 0s - loss: 0.7236 - mean_q: 5.9978
# Epoch 306/306
#  - 0s - loss: 0.5790 - mean_q: 6.0161
# Epoch 307/307
#  - 0s - loss: 0.2050 - mean_q: 6.1025
# Epoch 308/308
#  - 0s - loss: 0.5170 - mean_q: 5.5561
# Epoch 309/309
#  - 0s - loss: 0.3884 - mean_q: 5.8458
# Epoch 310/310
#  - 0s - loss: 0.0844 - mean_q: 5.8757
# Epoch 311/311
#  - 0s - loss: 0.2778 - mean_q: 6.1062
# Epoch 312/312
#  - 0s - loss: 0.5257 - mean_q: 6.0986
# Epoch 313/313
#  - 0s - loss: 0.2026 - mean_q: 6.4221
# Epoch 314/314
#  - 0s - loss: 0.4151 - mean_q: 6.2719
# Epoch 315/315
#  - 0s - loss: 0.2222 - mean_q: 6.4877
# Epoch 316/316
#  - 0s - loss: 0.1468 - mean_q: 6.4896
# Epoch 317/317
#  - 0s - loss: 0.2958 - mean_q: 6.5073
# Epoch 318/318
#  - 0s - loss: 0.2958 - mean_q: 6.2179
# Epoch 319/319
#  - 0s - loss: 0.4705 - mean_q: 6.3825
# Epoch 320/320
#  - 0s - loss: 0.5933 - mean_q: 6.4648
# Epoch 321/321
#  - 0s - loss: 0.4250 - mean_q: 6.2325
# Epoch 322/322
#  - 0s - loss: 0.3907 - mean_q: 6.6043
# Epoch 323/323
#  - 0s - loss: 0.2243 - mean_q: 6.2973
# Epoch 324/324
#  - 0s - loss: 0.5649 - mean_q: 6.2817
# Epoch 325/325
#  - 0s - loss: 0.5089 - mean_q: 6.7187
# Epoch 326/326
#  - 0s - loss: 0.4103 - mean_q: 6.0296
# Epoch 327/327
#  - 0s - loss: 0.2150 - mean_q: 6.1240
# Epoch 328/328
#  - 0s - loss: 0.2249 - mean_q: 6.2794
# Epoch 329/329
#  - 0s - loss: 0.5449 - mean_q: 6.2572
# Epoch 330/330
#  - 0s - loss: 0.2883 - mean_q: 6.4647
# Epoch 331/331
#  - 0s - loss: 0.2674 - mean_q: 5.7541
# Epoch 332/332
#  - 0s - loss: 0.4052 - mean_q: 6.0039
# Epoch 333/333
#  - 0s - loss: 0.5244 - mean_q: 5.9820
# Epoch 334/334
#  - 0s - loss: 0.3640 - mean_q: 6.2696
# Epoch 335/335
#  - 0s - loss: 0.4104 - mean_q: 6.5978
# Epoch 336/336
#  - 0s - loss: 0.2224 - mean_q: 6.5431
# Epoch 337/337
#  - 0s - loss: 0.0745 - mean_q: 6.3843
# Epoch 338/338
#  - 0s - loss: 0.3685 - mean_q: 6.2852
# Epoch 339/339
#  - 0s - loss: 0.5631 - mean_q: 6.6236
# Epoch 340/340
#  - 0s - loss: 0.5742 - mean_q: 6.4364
# Epoch 341/341
#  - 0s - loss: 0.0649 - mean_q: 6.3176
# Epoch 342/342
#  - 0s - loss: 0.3490 - mean_q: 6.1867
# Epoch 343/343
#  - 0s - loss: 0.2751 - mean_q: 6.0996
# Epoch 344/344
#  - 0s - loss: 0.3933 - mean_q: 6.2480
# Epoch 345/345
#  - 0s - loss: 0.3433 - mean_q: 6.0125
# Epoch 346/346
#  - 0s - loss: 0.6885 - mean_q: 6.6548
# Epoch 347/347
#  - 0s - loss: 0.4696 - mean_q: 6.1182
# Epoch 348/348
#  - 0s - loss: 0.1140 - mean_q: 6.1484
# Epoch 349/349
#  - 0s - loss: 0.3718 - mean_q: 6.2580
# Epoch 350/350
#  - 0s - loss: 0.4552 - mean_q: 5.8897
# Epoch 351/351
#  - 0s - loss: 0.3464 - mean_q: 6.0130
# Epoch 352/352
#  - 0s - loss: 0.3624 - mean_q: 6.7500
# Epoch 353/353
#  - 0s - loss: 0.4757 - mean_q: 6.2130
# Epoch 354/354
#  - 0s - loss: 0.2333 - mean_q: 6.2838
# Epoch 355/355
#  - 0s - loss: 0.2617 - mean_q: 6.4566
# Epoch 356/356
#  - 0s - loss: 0.1726 - mean_q: 6.2260
# Epoch 357/357
#  - 0s - loss: 0.3799 - mean_q: 6.3583
# Epoch 358/358
#  - 0s - loss: 0.4183 - mean_q: 6.0727
# Epoch 359/359
#  - 0s - loss: 0.6476 - mean_q: 6.0263
# Epoch 360/360
#  - 0s - loss: 0.2278 - mean_q: 6.4844
# Epoch 361/361
#  - 0s - loss: 0.3227 - mean_q: 6.4802
# Epoch 362/362
#  - 0s - loss: 0.1011 - mean_q: 5.9511
# Epoch 363/363
#  - 0s - loss: 0.2415 - mean_q: 6.3912
# Epoch 364/364
#  - 0s - loss: 0.2438 - mean_q: 6.2758
# Epoch 365/365
#  - 0s - loss: 0.2091 - mean_q: 6.6403
# Epoch 366/366
#  - 0s - loss: 0.4628 - mean_q: 6.4748
# Epoch 367/367
#  - 0s - loss: 0.4672 - mean_q: 6.0370
# Epoch 368/368
#  - 0s - loss: 0.2056 - mean_q: 5.9549
# Epoch 369/369
#  - 0s - loss: 0.4705 - mean_q: 6.1974
# Epoch 370/370
#  - 0s - loss: 0.3583 - mean_q: 6.2572
# Epoch 371/371
#  - 0s - loss: 0.3975 - mean_q: 6.1368
# Epoch 372/372
#  - 0s - loss: 0.1282 - mean_q: 6.5588
# Epoch 373/373
#  - 0s - loss: 0.3840 - mean_q: 6.8146
# Epoch 374/374
#  - 0s - loss: 0.0991 - mean_q: 6.5691
# Epoch 375/375
#  - 0s - loss: 0.4465 - mean_q: 6.5494
# Epoch 376/376
#  - 0s - loss: 0.1097 - mean_q: 6.1821
# Epoch 377/377
#  - 0s - loss: 0.2080 - mean_q: 6.0751
# Epoch 378/378
#  - 0s - loss: 0.3944 - mean_q: 6.0366
# Epoch 379/379
#  - 0s - loss: 0.1452 - mean_q: 6.1718
# Epoch 380/380
#  - 0s - loss: 0.3655 - mean_q: 6.5811
# Epoch 381/381
#  - 0s - loss: 0.0367 - mean_q: 6.1375
# Epoch 382/382
#  - 0s - loss: 0.1654 - mean_q: 6.4348
# Epoch 383/383
#  - 0s - loss: 0.4425 - mean_q: 6.3186
# Epoch 384/384
#  - 0s - loss: 0.3438 - mean_q: 6.0793
# Epoch 385/385
#  - 0s - loss: 0.4165 - mean_q: 6.1634
# Epoch 386/386
#  - 0s - loss: 0.3076 - mean_q: 6.0335
# Epoch 387/387
#  - 0s - loss: 0.4077 - mean_q: 6.4158
# Epoch 388/388
#  - 0s - loss: 0.3420 - mean_q: 6.4270
# Epoch 389/389
#  - 0s - loss: 0.5247 - mean_q: 6.5972
# Epoch 390/390
#  - 0s - loss: 0.3605 - mean_q: 6.3551
# Epoch 391/391
#  - 0s - loss: 0.3877 - mean_q: 6.0645
# Epoch 392/392
#  - 0s - loss: 0.2580 - mean_q: 5.8716
# Epoch 393/393
#  - 0s - loss: 0.7351 - mean_q: 6.0357
# Epoch 394/394
#  - 0s - loss: 0.2296 - mean_q: 6.2851
# Epoch 395/395
#  - 0s - loss: 0.4703 - mean_q: 6.6671
# Epoch 396/396
#  - 0s - loss: 0.1542 - mean_q: 6.3646
# Epoch 397/397
#  - 0s - loss: 0.3173 - mean_q: 6.1722
# Epoch 398/398
#  - 0s - loss: 0.2782 - mean_q: 6.0644
# Epoch 399/399
#  - 0s - loss: 0.2332 - mean_q: 6.5804
# Epoch 400/400
#  - 0s - loss: 0.1569 - mean_q: 6.0946
# Epoch 401/401
#  - 0s - loss: 0.4911 - mean_q: 6.4995
# Epoch 402/402
#  - 0s - loss: 0.6922 - mean_q: 6.6171
# Epoch 403/403
#  - 0s - loss: 0.5090 - mean_q: 6.5116
# Epoch 404/404
#  - 0s - loss: 0.9054 - mean_q: 7.2147
# Epoch 405/405
#  - 0s - loss: 0.3864 - mean_q: 7.0291
# Epoch 406/406
#  - 0s - loss: 0.4181 - mean_q: 6.5831
# Epoch 407/407
#  - 0s - loss: 0.2253 - mean_q: 7.4534
# Epoch 408/408
#  - 0s - loss: 0.5627 - mean_q: 7.2131
# Epoch 409/409
#  - 0s - loss: 0.8650 - mean_q: 7.1427
# Epoch 410/410
#  - 0s - loss: 0.3956 - mean_q: 7.1904
# Epoch 411/411
#  - 0s - loss: 0.3532 - mean_q: 7.0850
# Epoch 412/412
#  - 0s - loss: 0.7802 - mean_q: 7.8409
# Epoch 413/413
#  - 0s - loss: 0.1590 - mean_q: 7.7166
# Epoch 414/414
#  - 0s - loss: 0.5913 - mean_q: 7.6579
# Epoch 415/415
#  - 0s - loss: 0.3786 - mean_q: 7.5598
# Epoch 416/416
#  - 0s - loss: 0.3547 - mean_q: 7.6032
# Epoch 417/417
#  - 0s - loss: 0.6684 - mean_q: 7.4012
# Epoch 418/418
#  - 0s - loss: 0.6941 - mean_q: 7.4954
# Epoch 419/419
#  - 0s - loss: 0.3643 - mean_q: 7.3583
# Epoch 420/420
#  - 0s - loss: 0.1548 - mean_q: 7.2703
# Epoch 421/421
#  - 0s - loss: 0.4771 - mean_q: 7.3368
# Epoch 422/422
#  - 0s - loss: 0.1450 - mean_q: 7.4889
# Epoch 423/423
#  - 0s - loss: 0.4961 - mean_q: 6.7543
# Epoch 424/424
#  - 0s - loss: 0.9743 - mean_q: 7.0086
# Epoch 425/425
#  - 0s - loss: 0.9843 - mean_q: 7.2355
# Epoch 426/426
#  - 0s - loss: 0.2075 - mean_q: 6.9421
# Epoch 427/427
#  - 0s - loss: 0.4060 - mean_q: 7.1245
# Epoch 428/428
#  - 0s - loss: 0.5331 - mean_q: 6.6260
# Epoch 429/429
#  - 0s - loss: 0.3382 - mean_q: 7.1972
# Epoch 430/430
#  - 0s - loss: 0.7804 - mean_q: 7.1819
# Epoch 431/431
#  - 0s - loss: 0.4255 - mean_q: 7.8451
# Epoch 432/432
#  - 0s - loss: 0.5797 - mean_q: 7.3221
# Epoch 433/433
#  - 0s - loss: 0.6741 - mean_q: 7.5897
# Epoch 434/434
#  - 0s - loss: 0.5531 - mean_q: 7.4846
# Epoch 435/435
#  - 0s - loss: 0.7374 - mean_q: 7.3225
# Epoch 436/436
#  - 0s - loss: 0.8043 - mean_q: 7.1845
# Epoch 437/437
#  - 0s - loss: 0.5852 - mean_q: 7.3414
# Epoch 438/438
#  - 0s - loss: 0.1807 - mean_q: 7.0916
# Epoch 439/439
#  - 0s - loss: 0.4419 - mean_q: 7.2271
# Epoch 440/440
#  - 0s - loss: 0.2419 - mean_q: 7.1845
# Epoch 441/441
#  - 0s - loss: 0.2008 - mean_q: 7.2876
# Epoch 442/442
#  - 0s - loss: 0.4726 - mean_q: 7.9961
# Epoch 443/443
#  - 0s - loss: 0.8830 - mean_q: 7.2682
# Epoch 444/444
#  - 0s - loss: 0.6623 - mean_q: 7.7358
# Epoch 445/445
#  - 0s - loss: 0.3201 - mean_q: 7.7988
# Epoch 446/446
#  - 0s - loss: 0.3339 - mean_q: 7.1676
# Epoch 447/447
#  - 0s - loss: 0.3306 - mean_q: 7.0503
# Epoch 448/448
#  - 0s - loss: 0.3865 - mean_q: 7.4449
# Epoch 449/449
#  - 0s - loss: 0.4782 - mean_q: 7.5958
# Epoch 450/450
#  - 0s - loss: 0.5010 - mean_q: 7.4481
# Epoch 451/451
#  - 0s - loss: 0.7159 - mean_q: 7.2465
# Epoch 452/452
#  - 0s - loss: 0.2387 - mean_q: 7.3209
# Epoch 453/453
#  - 0s - loss: 0.3167 - mean_q: 7.0728
# Epoch 454/454
#  - 0s - loss: 0.3759 - mean_q: 7.5362
# Epoch 455/455
#  - 0s - loss: 0.4663 - mean_q: 7.5020
# Epoch 456/456
#  - 0s - loss: 0.3331 - mean_q: 6.7797
# Epoch 457/457
#  - 0s - loss: 0.3822 - mean_q: 6.9475
# Epoch 458/458
#  - 0s - loss: 0.3996 - mean_q: 7.6707
# Epoch 459/459
#  - 0s - loss: 0.1840 - mean_q: 7.2401
# Epoch 460/460
#  - 0s - loss: 0.2803 - mean_q: 7.3699
# Epoch 461/461
#  - 0s - loss: 0.8330 - mean_q: 7.8465
# Epoch 462/462
#  - 0s - loss: 0.1041 - mean_q: 7.5368
# Epoch 463/463
#  - 0s - loss: 0.2739 - mean_q: 7.8772
# Epoch 464/464
#  - 0s - loss: 0.4039 - mean_q: 7.2071
# Epoch 465/465
#  - 0s - loss: 0.6391 - mean_q: 7.3199
# Epoch 466/466
#  - 0s - loss: 0.3503 - mean_q: 7.0757
# Epoch 467/467
#  - 0s - loss: 0.2347 - mean_q: 7.3847
# Epoch 468/468
#  - 0s - loss: 0.2863 - mean_q: 7.4776
# Epoch 469/469
#  - 0s - loss: 0.2787 - mean_q: 7.2100
# Epoch 470/470
#  - 0s - loss: 0.3780 - mean_q: 7.2593
# Epoch 471/471
#  - 0s - loss: 0.3137 - mean_q: 7.4373
# Epoch 472/472
#  - 0s - loss: 0.4497 - mean_q: 7.2398
# Epoch 473/473
#  - 0s - loss: 0.2403 - mean_q: 7.1467
# Epoch 474/474
#  - 0s - loss: 0.5362 - mean_q: 7.0632
# Epoch 475/475
#  - 0s - loss: 0.2781 - mean_q: 7.7517
# Epoch 476/476
#  - 0s - loss: 0.1477 - mean_q: 7.7575
# Epoch 477/477
#  - 0s - loss: 0.2283 - mean_q: 7.5116
# Epoch 478/478
#  - 0s - loss: 0.3168 - mean_q: 7.5223
# Epoch 479/479
#  - 0s - loss: 0.1757 - mean_q: 7.2431
# Epoch 480/480
#  - 0s - loss: 0.4546 - mean_q: 7.6413
# Epoch 481/481
#  - 0s - loss: 0.3740 - mean_q: 7.6281
# Epoch 482/482
#  - 0s - loss: 0.4737 - mean_q: 7.5984
# Epoch 483/483
#  - 0s - loss: 0.3763 - mean_q: 7.4515
# Epoch 484/484
#  - 0s - loss: 0.4337 - mean_q: 7.0995
# Epoch 485/485
#  - 0s - loss: 0.1121 - mean_q: 7.4094
# Epoch 486/486
#  - 0s - loss: 0.2114 - mean_q: 7.4947
# Epoch 487/487
#  - 0s - loss: 0.2693 - mean_q: 6.9034
# Epoch 488/488
#  - 0s - loss: 0.4821 - mean_q: 6.9243
# Epoch 489/489
#  - 0s - loss: 0.7469 - mean_q: 7.2783
# Epoch 490/490
#  - 0s - loss: 0.3798 - mean_q: 7.4315
# Epoch 491/491
#  - 0s - loss: 0.6095 - mean_q: 7.5783
# Epoch 492/492
#  - 0s - loss: 0.6149 - mean_q: 7.2252
# Epoch 493/493
#  - 0s - loss: 0.6662 - mean_q: 6.8608
# Epoch 494/494
#  - 0s - loss: 0.5062 - mean_q: 6.9765
# Epoch 495/495
#  - 0s - loss: 0.1796 - mean_q: 7.7971
# Epoch 496/496
#  - 0s - loss: 0.2829 - mean_q: 7.9723
# Epoch 497/497
#  - 0s - loss: 0.3520 - mean_q: 7.5835
# Epoch 498/498
#  - 0s - loss: 1.0030 - mean_q: 7.5104
# Epoch 499/499
#  - 0s - loss: 0.3523 - mean_q: 7.1111
# Epoch 500/500
#  - 0s - loss: 0.4386 - mean_q: 7.2795
# Epoch 501/501
#  - 0s - loss: 0.7480 - mean_q: 7.6210
# Epoch 502/502
#  - 0s - loss: 0.7247 - mean_q: 8.0528
# Epoch 503/503
#  - 0s - loss: 0.5945 - mean_q: 7.9077
# Epoch 504/504
#  - 0s - loss: 0.4265 - mean_q: 7.7626
# Epoch 505/505
#  - 0s - loss: 0.4674 - mean_q: 8.4721
# Epoch 506/506
#  - 0s - loss: 0.4868 - mean_q: 8.2307
# Epoch 507/507
#  - 0s - loss: 0.7136 - mean_q: 8.7863
# Epoch 508/508
#  - 0s - loss: 0.4188 - mean_q: 8.8197
# Epoch 509/509
#  - 0s - loss: 0.6637 - mean_q: 8.2768
# Epoch 510/510
#  - 0s - loss: 0.3953 - mean_q: 8.5871
# Epoch 511/511
#  - 0s - loss: 0.5734 - mean_q: 8.4157
# Epoch 512/512
#  - 0s - loss: 1.2801 - mean_q: 9.7360
# Epoch 513/513
#  - 0s - loss: 0.4803 - mean_q: 8.6650
# Epoch 514/514
#  - 0s - loss: 0.2117 - mean_q: 8.4767
# Epoch 515/515
#  - 0s - loss: 0.3857 - mean_q: 8.5174
# Epoch 516/516
#  - 0s - loss: 0.3370 - mean_q: 8.6960
# Epoch 517/517
#  - 0s - loss: 0.4263 - mean_q: 9.1970
# Epoch 518/518
#  - 0s - loss: 0.4985 - mean_q: 9.3222
# Epoch 519/519
#  - 0s - loss: 0.3072 - mean_q: 8.2465
# Epoch 520/520
#  - 0s - loss: 0.4043 - mean_q: 8.5304
# Epoch 521/521
#  - 0s - loss: 0.4577 - mean_q: 8.6601
# Epoch 522/522
#  - 0s - loss: 0.6711 - mean_q: 8.5751
# Epoch 523/523
#  - 0s - loss: 0.6414 - mean_q: 8.4746
# Epoch 524/524
#  - 0s - loss: 1.5335 - mean_q: 8.2916
# Epoch 525/525
#  - 0s - loss: 0.2042 - mean_q: 8.0218
# Epoch 526/526
#  - 0s - loss: 0.2660 - mean_q: 8.3010
# Epoch 527/527
#  - 0s - loss: 0.2222 - mean_q: 9.0046
# Epoch 528/528
#  - 0s - loss: 0.1435 - mean_q: 8.1140
# Epoch 529/529
#  - 0s - loss: 0.4398 - mean_q: 9.3028
# Epoch 530/530
#  - 0s - loss: 0.5909 - mean_q: 8.8268
# Epoch 531/531
#  - 0s - loss: 0.5712 - mean_q: 9.1201
# Epoch 532/532
#  - 0s - loss: 0.3594 - mean_q: 9.4134
# Epoch 533/533
#  - 0s - loss: 0.2005 - mean_q: 8.5709
# Epoch 534/534
#  - 0s - loss: 0.4467 - mean_q: 8.0235
# Epoch 535/535
#  - 0s - loss: 0.4150 - mean_q: 8.1211
# Epoch 536/536
#  - 0s - loss: 0.8563 - mean_q: 8.8486
# Epoch 537/537
#  - 0s - loss: 0.5244 - mean_q: 8.5032
# Epoch 538/538
#  - 0s - loss: 0.3698 - mean_q: 8.8770
# Epoch 539/539
#  - 0s - loss: 0.4905 - mean_q: 8.3682
# Epoch 540/540
#  - 0s - loss: 0.3619 - mean_q: 8.7785
# Epoch 541/541
#  - 0s - loss: 0.9207 - mean_q: 8.2822
# Epoch 542/542
#  - 0s - loss: 0.5764 - mean_q: 8.4429
# Epoch 543/543
#  - 0s - loss: 0.7171 - mean_q: 8.2586
# Epoch 544/544
#  - 0s - loss: 0.2011 - mean_q: 8.9691
# Epoch 545/545
#  - 0s - loss: 0.6392 - mean_q: 8.4457
# Epoch 546/546
#  - 0s - loss: 0.6729 - mean_q: 8.6891
# Epoch 547/547
#  - 0s - loss: 1.0603 - mean_q: 8.2110
# Epoch 548/548
#  - 0s - loss: 0.2637 - mean_q: 8.4351
# Epoch 549/549
#  - 0s - loss: 0.4539 - mean_q: 9.1229
# Epoch 550/550
#  - 0s - loss: 0.4995 - mean_q: 8.4719
# Epoch 551/551
#  - 0s - loss: 0.4830 - mean_q: 9.0628
# Epoch 552/552
#  - 0s - loss: 0.5846 - mean_q: 8.9892
# Epoch 553/553
#  - 0s - loss: 0.5396 - mean_q: 8.0728
# Epoch 554/554
#  - 0s - loss: 0.8546 - mean_q: 8.9934
# Epoch 555/555
#  - 0s - loss: 0.2282 - mean_q: 8.0140
# Epoch 556/556
#  - 0s - loss: 0.5563 - mean_q: 8.5880
# Epoch 557/557
#  - 0s - loss: 0.4365 - mean_q: 8.8195
# Epoch 558/558
#  - 0s - loss: 0.0821 - mean_q: 8.5261
# Epoch 559/559
#  - 0s - loss: 0.5428 - mean_q: 8.2783
# Epoch 560/560
#  - 0s - loss: 0.2508 - mean_q: 8.5676
# Epoch 561/561
#  - 0s - loss: 0.3490 - mean_q: 8.0172
# Epoch 562/562
#  - 0s - loss: 0.6946 - mean_q: 7.7147
# Epoch 563/563
#  - 0s - loss: 1.3210 - mean_q: 8.6127
# Epoch 564/564
#  - 0s - loss: 0.6237 - mean_q: 8.5459
# Epoch 565/565
#  - 0s - loss: 0.5648 - mean_q: 8.0894
# Epoch 566/566
#  - 0s - loss: 0.4835 - mean_q: 8.6176
# Epoch 567/567
#  - 0s - loss: 0.8053 - mean_q: 8.8773
# Epoch 568/568
#  - 0s - loss: 0.4391 - mean_q: 8.4773
# Epoch 569/569
#  - 0s - loss: 0.3061 - mean_q: 7.8769
# Epoch 570/570
#  - 0s - loss: 0.8030 - mean_q: 8.4053
# Epoch 571/571
#  - 0s - loss: 0.3546 - mean_q: 8.5859
# Epoch 572/572
#  - 0s - loss: 0.5234 - mean_q: 8.3209
# Epoch 573/573
#  - 0s - loss: 0.5418 - mean_q: 8.6375
# Epoch 574/574
#  - 0s - loss: 0.4451 - mean_q: 8.6172
# Epoch 575/575
#  - 0s - loss: 0.2307 - mean_q: 8.5516
# Epoch 576/576
#  - 0s - loss: 0.3441 - mean_q: 8.7248
# Epoch 577/577
#  - 0s - loss: 0.4533 - mean_q: 8.3387
# Epoch 578/578
#  - 0s - loss: 0.2833 - mean_q: 8.0881
# Epoch 579/579
#  - 0s - loss: 0.3862 - mean_q: 8.4465
# Epoch 580/580
#  - 0s - loss: 0.6237 - mean_q: 8.4813
# Epoch 581/581
#  - 0s - loss: 0.4043 - mean_q: 8.1002
# Epoch 582/582
#  - 0s - loss: 0.8602 - mean_q: 8.1280
# Epoch 583/583
#  - 0s - loss: 0.2266 - mean_q: 8.0628
# Epoch 584/584
#  - 0s - loss: 0.9404 - mean_q: 8.7386
# Epoch 585/585
#  - 0s - loss: 0.3863 - mean_q: 8.3346
# Epoch 586/586
#  - 0s - loss: 0.9608 - mean_q: 8.2626
# Epoch 587/587
#  - 0s - loss: 0.7160 - mean_q: 8.1704
# Epoch 588/588
#  - 0s - loss: 0.6415 - mean_q: 8.2118
# Epoch 589/589
#  - 0s - loss: 0.6827 - mean_q: 8.2016
# Epoch 590/590
#  - 0s - loss: 0.9848 - mean_q: 8.4985
# Epoch 591/591
#  - 0s - loss: 0.1934 - mean_q: 8.8071
# Epoch 592/592
#  - 0s - loss: 0.3438 - mean_q: 7.9090
# Epoch 593/593
#  - 0s - loss: 0.4959 - mean_q: 8.3971
# Epoch 594/594
#  - 0s - loss: 0.5269 - mean_q: 9.3818
# Epoch 595/595
#  - 0s - loss: 0.7980 - mean_q: 8.4396
# Epoch 596/596
#  - 0s - loss: 0.5961 - mean_q: 8.5926
# Epoch 597/597
#  - 0s - loss: 0.9631 - mean_q: 8.4258
# Epoch 598/598
#  - 0s - loss: 0.3312 - mean_q: 8.4589
# Epoch 599/599
#  - 0s - loss: 0.7673 - mean_q: 9.0889
# Epoch 600/600
#  - 0s - loss: 0.4938 - mean_q: 8.0862
# Epoch 601/601
#  - 0s - loss: 1.1446 - mean_q: 8.9647
# Epoch 602/602
#  - 0s - loss: 0.4453 - mean_q: 9.0257
# Epoch 603/603
#  - 0s - loss: 0.5950 - mean_q: 8.4991
# Epoch 604/604
#  - 0s - loss: 0.5599 - mean_q: 9.3621
# Epoch 605/605
#  - 0s - loss: 0.2798 - mean_q: 9.6334
# Epoch 606/606
#  - 0s - loss: 0.8917 - mean_q: 10.0819
# Epoch 607/607
#  - 0s - loss: 0.8275 - mean_q: 9.9456
# Epoch 608/608
#  - 0s - loss: 0.2350 - mean_q: 9.2913
# Epoch 609/609
#  - 0s - loss: 0.6264 - mean_q: 10.0102
# Epoch 610/610
#  - 0s - loss: 0.0927 - mean_q: 9.9772
# Epoch 611/611
#  - 0s - loss: 0.7607 - mean_q: 9.7730
# Epoch 612/612
#  - 0s - loss: 0.9276 - mean_q: 9.9125
# Epoch 613/613
#  - 0s - loss: 0.7920 - mean_q: 9.6883
# Epoch 614/614
#  - 0s - loss: 0.2027 - mean_q: 10.5937
# Epoch 615/615
#  - 0s - loss: 0.5842 - mean_q: 9.7148
# Epoch 616/616
#  - 0s - loss: 0.3400 - mean_q: 9.0993
# Epoch 617/617
#  - 0s - loss: 1.4717 - mean_q: 9.6671
# Epoch 618/618
#  - 0s - loss: 0.7968 - mean_q: 9.3040
# Epoch 619/619
#  - 0s - loss: 0.9818 - mean_q: 9.4086
# Epoch 620/620
#  - 0s - loss: 0.5403 - mean_q: 9.3827
# Epoch 621/621
#  - 0s - loss: 2.2339 - mean_q: 9.5594
# Epoch 622/622
#  - 0s - loss: 0.8913 - mean_q: 9.2263
# Epoch 623/623
#  - 0s - loss: 0.6221 - mean_q: 8.7012
# Epoch 624/624
#  - 0s - loss: 0.7256 - mean_q: 9.3678
# Epoch 625/625
#  - 0s - loss: 0.4651 - mean_q: 9.3683
# Epoch 626/626
#  - 0s - loss: 0.8951 - mean_q: 9.4732
# Epoch 627/627
#  - 0s - loss: 0.5510 - mean_q: 9.7720
# Epoch 628/628
#  - 0s - loss: 0.4899 - mean_q: 9.8215
# Epoch 629/629
#  - 0s - loss: 0.3040 - mean_q: 8.8182
# Epoch 630/630
#  - 0s - loss: 0.3198 - mean_q: 9.5133
# Epoch 631/631
#  - 0s - loss: 1.5011 - mean_q: 10.2315
# Epoch 632/632
#  - 0s - loss: 0.3395 - mean_q: 9.4719
# Epoch 633/633
#  - 0s - loss: 0.9946 - mean_q: 9.2900
# Epoch 634/634
#  - 0s - loss: 0.6470 - mean_q: 8.9726
# Epoch 635/635
#  - 0s - loss: 1.1959 - mean_q: 9.0535
# Epoch 636/636
#  - 0s - loss: 1.0478 - mean_q: 8.7165
# Epoch 637/637
#  - 0s - loss: 0.5836 - mean_q: 9.8118
# Epoch 638/638
#  - 0s - loss: 0.5865 - mean_q: 8.6442
# Epoch 639/639
#  - 0s - loss: 0.1479 - mean_q: 9.1906
# Epoch 640/640
#  - 0s - loss: 0.7888 - mean_q: 9.5237
# Epoch 641/641
#  - 0s - loss: 0.8254 - mean_q: 9.3659
# Epoch 642/642
#  - 0s - loss: 0.8550 - mean_q: 9.2636
# Epoch 643/643
#  - 0s - loss: 0.4660 - mean_q: 10.2423
# Epoch 644/644
#  - 0s - loss: 0.6801 - mean_q: 9.4564
# Epoch 645/645
#  - 0s - loss: 0.5326 - mean_q: 10.1258
# Epoch 646/646
#  - 0s - loss: 0.3474 - mean_q: 9.9479
# Epoch 647/647
#  - 0s - loss: 0.2955 - mean_q: 9.3107
# Epoch 648/648
#  - 0s - loss: 0.6791 - mean_q: 9.9832
# Epoch 649/649
#  - 0s - loss: 0.8437 - mean_q: 9.8957
# Epoch 650/650
#  - 0s - loss: 0.6027 - mean_q: 9.6413
# Epoch 651/651
#  - 0s - loss: 0.4728 - mean_q: 9.5265
# Epoch 652/652
#  - 0s - loss: 0.3556 - mean_q: 9.3648
# Epoch 653/653
#  - 0s - loss: 0.6919 - mean_q: 9.5657
# Epoch 654/654
#  - 0s - loss: 0.9143 - mean_q: 9.1315
# Epoch 655/655
#  - 0s - loss: 0.3649 - mean_q: 9.9547
# Epoch 656/656
#  - 0s - loss: 0.7559 - mean_q: 9.3497
# Epoch 657/657
#  - 0s - loss: 0.6622 - mean_q: 9.6653
# Epoch 658/658
#  - 0s - loss: 0.4205 - mean_q: 9.7133
# Epoch 659/659
#  - 0s - loss: 0.8180 - mean_q: 9.1611
# Epoch 660/660
#  - 0s - loss: 0.2855 - mean_q: 9.3825
# Epoch 661/661
#  - 0s - loss: 0.4129 - mean_q: 9.4628
# Epoch 662/662
#  - 0s - loss: 0.3979 - mean_q: 9.8841
# Epoch 663/663
#  - 0s - loss: 0.2683 - mean_q: 9.6678
# Epoch 664/664
#  - 0s - loss: 0.8389 - mean_q: 9.6475
# Epoch 665/665
#  - 0s - loss: 0.8846 - mean_q: 9.4045
# Epoch 666/666
#  - 0s - loss: 1.1086 - mean_q: 10.4912
# Epoch 667/667
#  - 0s - loss: 0.8633 - mean_q: 9.9666
# Epoch 668/668
#  - 0s - loss: 0.8290 - mean_q: 9.1872
# Epoch 669/669
#  - 0s - loss: 0.8032 - mean_q: 9.6599
# Epoch 670/670
#  - 0s - loss: 0.1986 - mean_q: 9.7073
# Epoch 671/671
#  - 0s - loss: 0.6392 - mean_q: 9.3159
# Epoch 672/672
#  - 0s - loss: 1.1380 - mean_q: 9.1087
# Epoch 673/673
#  - 0s - loss: 0.6917 - mean_q: 9.9196
# Epoch 674/674
#  - 0s - loss: 0.2940 - mean_q: 9.6563
# Epoch 675/675
#  - 0s - loss: 0.4225 - mean_q: 9.9434
# Epoch 676/676
#  - 0s - loss: 0.5832 - mean_q: 9.9805
# Epoch 677/677
#  - 0s - loss: 0.2831 - mean_q: 9.5225
# Epoch 678/678
#  - 0s - loss: 0.9103 - mean_q: 9.3442
# Epoch 679/679
#  - 0s - loss: 0.5083 - mean_q: 9.3258
# Epoch 680/680
#  - 0s - loss: 0.7731 - mean_q: 9.2470
# Epoch 681/681
#  - 0s - loss: 0.6031 - mean_q: 9.1036
# Epoch 682/682
#  - 0s - loss: 0.3855 - mean_q: 9.2773
# Epoch 683/683
#  - 0s - loss: 0.2056 - mean_q: 8.9157
# Epoch 684/684
#  - 0s - loss: 0.3435 - mean_q: 9.5356
# Epoch 685/685
#  - 0s - loss: 0.3610 - mean_q: 9.3358
# Epoch 686/686
#  - 0s - loss: 1.0110 - mean_q: 9.3868
# Epoch 687/687
#  - 0s - loss: 0.2779 - mean_q: 8.8373
# Epoch 688/688
#  - 0s - loss: 0.7212 - mean_q: 9.8836
# Epoch 689/689
#  - 0s - loss: 0.5839 - mean_q: 8.9711
# Epoch 690/690
#  - 0s - loss: 0.5679 - mean_q: 9.8420
# Epoch 691/691
#  - 0s - loss: 0.2279 - mean_q: 9.4147
# Epoch 692/692
#  - 0s - loss: 0.0701 - mean_q: 9.6418
# Epoch 693/693
#  - 0s - loss: 0.4893 - mean_q: 10.2518
# Epoch 694/694
#  - 0s - loss: 0.7229 - mean_q: 9.3487
# Epoch 695/695
#  - 0s - loss: 0.4787 - mean_q: 9.1397
# Epoch 696/696
#  - 0s - loss: 0.5705 - mean_q: 8.8934
# Epoch 697/697
#  - 0s - loss: 0.2718 - mean_q: 10.6668
# Epoch 698/698
#  - 0s - loss: 0.3890 - mean_q: 9.5339
# Epoch 699/699
#  - 0s - loss: 0.5751 - mean_q: 9.4696
# Epoch 700/700
#  - 0s - loss: 0.6650 - mean_q: 9.7507
# Epoch 701/701
#  - 0s - loss: 0.7774 - mean_q: 9.3114
# Epoch 702/702
#  - 0s - loss: 0.8712 - mean_q: 10.1845
# Epoch 703/703
#  - 0s - loss: 0.8312 - mean_q: 10.1775
# Epoch 704/704
#  - 0s - loss: 0.6148 - mean_q: 9.9596
# Epoch 705/705
#  - 0s - loss: 0.6109 - mean_q: 10.4296
# Epoch 706/706
#  - 0s - loss: 0.6792 - mean_q: 10.3167
# Epoch 707/707
#  - 0s - loss: 0.5825 - mean_q: 10.2987
# Epoch 708/708
#  - 0s - loss: 0.1861 - mean_q: 10.7878
# Epoch 709/709
#  - 0s - loss: 0.7147 - mean_q: 10.4596
# Epoch 710/710
#  - 0s - loss: 0.4909 - mean_q: 10.2214
# Epoch 711/711
#  - 0s - loss: 0.3098 - mean_q: 10.4475
# Epoch 712/712
#  - 0s - loss: 1.5122 - mean_q: 10.4734
# Epoch 713/713
#  - 0s - loss: 0.2141 - mean_q: 10.3377
# Epoch 714/714
#  - 0s - loss: 0.5511 - mean_q: 10.2903
# Epoch 715/715
#  - 0s - loss: 0.4788 - mean_q: 11.2092
# Epoch 716/716
#  - 0s - loss: 0.7027 - mean_q: 10.8621
# Epoch 717/717
#  - 0s - loss: 0.9028 - mean_q: 9.6535
# Epoch 718/718
#  - 0s - loss: 1.2268 - mean_q: 10.9819
# Epoch 719/719
#  - 0s - loss: 1.1093 - mean_q: 10.1315
# Epoch 720/720
#  - 0s - loss: 0.2367 - mean_q: 10.6562
# Epoch 721/721
#  - 0s - loss: 1.0171 - mean_q: 10.0637
# Epoch 722/722
#  - 0s - loss: 1.0266 - mean_q: 9.0958
# Epoch 723/723
#  - 0s - loss: 0.6441 - mean_q: 10.7720
# Epoch 724/724
#  - 0s - loss: 1.5548 - mean_q: 9.8091
# Epoch 725/725
#  - 0s - loss: 0.6698 - mean_q: 10.9107
# Epoch 726/726
#  - 0s - loss: 0.7151 - mean_q: 9.6345
# Epoch 727/727
#  - 0s - loss: 0.5265 - mean_q: 10.4963
# Epoch 728/728
#  - 0s - loss: 1.4156 - mean_q: 10.5473
# Epoch 729/729
#  - 0s - loss: 0.4553 - mean_q: 10.4764
# Epoch 730/730
#  - 0s - loss: 0.5940 - mean_q: 10.3857
# Epoch 731/731
#  - 0s - loss: 0.7177 - mean_q: 9.9419
# Epoch 732/732
#  - 0s - loss: 0.6768 - mean_q: 9.7872
# Epoch 733/733
#  - 0s - loss: 1.0050 - mean_q: 11.0147
# Epoch 734/734
#  - 0s - loss: 0.4518 - mean_q: 10.3705
# Epoch 735/735
#  - 0s - loss: 0.3021 - mean_q: 11.2729
# Epoch 736/736
#  - 0s - loss: 0.7704 - mean_q: 10.3206
# Epoch 737/737
#  - 0s - loss: 0.4218 - mean_q: 10.6634
# Epoch 738/738
#  - 0s - loss: 0.5542 - mean_q: 10.2821
# Epoch 739/739
#  - 0s - loss: 0.5200 - mean_q: 10.5874
# Epoch 740/740
#  - 0s - loss: 1.0636 - mean_q: 10.4282
# Epoch 741/741
#  - 0s - loss: 1.0507 - mean_q: 10.8069
# Epoch 742/742
#  - 0s - loss: 0.7201 - mean_q: 10.0277
# Epoch 743/743
#  - 0s - loss: 0.3708 - mean_q: 9.8289
# Epoch 744/744
#  - 0s - loss: 0.5817 - mean_q: 10.5183
# Epoch 745/745
#  - 0s - loss: 0.9454 - mean_q: 10.1397
# Epoch 746/746
#  - 0s - loss: 0.9600 - mean_q: 10.3608
# Epoch 747/747
#  - 0s - loss: 0.5674 - mean_q: 10.3356
# Epoch 748/748
#  - 0s - loss: 0.4231 - mean_q: 9.7240
# Epoch 749/749
#  - 0s - loss: 0.4267 - mean_q: 10.4867
# Epoch 750/750
#  - 0s - loss: 0.6973 - mean_q: 10.3997
# Epoch 751/751
#  - 0s - loss: 1.0869 - mean_q: 10.1790
# Epoch 752/752
#  - 0s - loss: 1.4585 - mean_q: 10.7359
# Epoch 753/753
#  - 0s - loss: 0.4442 - mean_q: 11.0325
# Epoch 754/754
#  - 0s - loss: 1.2462 - mean_q: 10.1454
# Epoch 755/755
#  - 0s - loss: 0.6127 - mean_q: 10.5634
# Epoch 756/756
#  - 0s - loss: 0.5231 - mean_q: 11.5307
# Epoch 757/757
#  - 0s - loss: 0.8840 - mean_q: 10.8276
# Epoch 758/758
#  - 0s - loss: 0.8038 - mean_q: 9.7518
# Epoch 759/759
#  - 0s - loss: 0.5060 - mean_q: 11.5131
# Epoch 760/760
#  - 0s - loss: 0.3104 - mean_q: 10.0981
# Epoch 761/761
#  - 0s - loss: 0.8426 - mean_q: 10.4361
# Epoch 762/762
#  - 0s - loss: 0.5066 - mean_q: 9.7115
# Epoch 763/763
#  - 0s - loss: 0.7492 - mean_q: 11.6327
# Epoch 764/764
#  - 0s - loss: 0.8665 - mean_q: 10.0071
# Epoch 765/765
#  - 0s - loss: 0.8510 - mean_q: 11.1653
# Epoch 766/766
#  - 0s - loss: 0.9628 - mean_q: 11.5807
# Epoch 767/767
#  - 0s - loss: 0.7643 - mean_q: 11.2314
# Epoch 768/768
#  - 0s - loss: 0.4734 - mean_q: 10.8549
# Epoch 769/769
#  - 0s - loss: 0.6476 - mean_q: 10.5242
# Epoch 770/770
#  - 0s - loss: 1.0359 - mean_q: 10.2091
# Epoch 771/771
#  - 0s - loss: 1.4294 - mean_q: 10.7818
# Epoch 772/772
#  - 0s - loss: 1.2568 - mean_q: 9.9540
# Epoch 773/773
#  - 0s - loss: 1.1735 - mean_q: 10.3288
# Epoch 774/774
#  - 0s - loss: 0.5037 - mean_q: 10.3597
# Epoch 775/775
#  - 0s - loss: 0.8672 - mean_q: 10.6529
# Epoch 776/776
#  - 0s - loss: 0.3934 - mean_q: 10.3664
# Epoch 777/777
#  - 0s - loss: 0.7349 - mean_q: 10.5018
# Epoch 778/778
#  - 0s - loss: 0.3645 - mean_q: 10.2780
# Epoch 779/779
#  - 0s - loss: 0.6127 - mean_q: 10.0653
# Epoch 780/780
#  - 0s - loss: 0.3197 - mean_q: 10.6213
# Epoch 781/781
#  - 0s - loss: 0.6172 - mean_q: 10.6381
# Epoch 782/782
#  - 0s - loss: 1.0931 - mean_q: 10.6785
# Epoch 783/783
#  - 0s - loss: 0.4369 - mean_q: 10.2472
# Epoch 784/784
#  - 0s - loss: 0.1842 - mean_q: 10.3151
# Epoch 785/785
#  - 0s - loss: 1.3667 - mean_q: 9.9909
# Epoch 786/786
#  - 0s - loss: 0.5749 - mean_q: 10.5172
# Epoch 787/787
#  - 0s - loss: 0.3008 - mean_q: 10.2965
# Epoch 788/788
#  - 0s - loss: 0.4345 - mean_q: 10.1205
# Epoch 789/789
#  - 0s - loss: 0.6296 - mean_q: 10.5160
# Epoch 790/790
#  - 0s - loss: 1.0224 - mean_q: 10.0715
# Epoch 791/791
#  - 0s - loss: 0.3066 - mean_q: 10.1215
# Epoch 792/792
#  - 0s - loss: 1.0716 - mean_q: 10.7389
# Epoch 793/793
#  - 0s - loss: 0.8089 - mean_q: 10.3973
# Epoch 794/794
#  - 0s - loss: 0.6528 - mean_q: 10.9162
# Epoch 795/795
#  - 0s - loss: 0.6489 - mean_q: 10.2087
# Epoch 796/796
#  - 0s - loss: 0.9581 - mean_q: 11.1174
# Epoch 797/797
#  - 0s - loss: 0.4550 - mean_q: 11.2557
# Epoch 798/798
#  - 0s - loss: 0.5280 - mean_q: 10.5153
# Epoch 799/799
#  - 0s - loss: 0.5679 - mean_q: 8.9514
# Epoch 800/800
#  - 0s - loss: 1.0174 - mean_q: 10.2083
# Epoch 801/801
#  - 0s - loss: 0.2596 - mean_q: 11.0372
# Epoch 802/802
#  - 0s - loss: 0.5963 - mean_q: 10.8716
# Epoch 803/803
#  - 0s - loss: 0.6796 - mean_q: 10.6784
# Epoch 804/804
#  - 0s - loss: 0.9126 - mean_q: 11.1255
# Epoch 805/805
#  - 0s - loss: 0.4924 - mean_q: 9.8873
# Epoch 806/806
#  - 0s - loss: 0.5463 - mean_q: 10.6620
# Epoch 807/807
#  - 0s - loss: 0.2657 - mean_q: 10.6933
# Epoch 808/808
#  - 0s - loss: 0.3794 - mean_q: 12.0624
# Epoch 809/809
#  - 0s - loss: 1.3468 - mean_q: 11.6279
# Epoch 810/810
#  - 0s - loss: 1.0556 - mean_q: 10.4378
# Epoch 811/811
#  - 0s - loss: 0.3832 - mean_q: 10.9834
# Epoch 812/812
#  - 0s - loss: 0.3181 - mean_q: 11.4421
# Epoch 813/813
#  - 0s - loss: 0.6156 - mean_q: 11.6528
# Epoch 814/814
#  - 0s - loss: 0.7306 - mean_q: 10.8276
# Epoch 815/815
#  - 0s - loss: 0.5678 - mean_q: 11.1439
# Epoch 816/816
#  - 0s - loss: 0.6831 - mean_q: 10.8337
# Epoch 817/817
#  - 0s - loss: 1.4800 - mean_q: 11.1418
# Epoch 818/818
#  - 0s - loss: 0.5226 - mean_q: 10.8102
# Epoch 819/819
#  - 0s - loss: 1.1239 - mean_q: 10.6358
# Epoch 820/820
#  - 0s - loss: 0.2683 - mean_q: 11.3114
# Epoch 821/821
#  - 0s - loss: 1.0690 - mean_q: 11.3838
# Epoch 822/822
#  - 0s - loss: 0.7647 - mean_q: 11.4560
# Epoch 823/823
#  - 0s - loss: 1.0413 - mean_q: 11.2774
# Epoch 824/824
#  - 0s - loss: 0.7231 - mean_q: 10.9397
# Epoch 825/825
#  - 0s - loss: 0.3237 - mean_q: 10.0956
# Epoch 826/826
#  - 0s - loss: 0.4310 - mean_q: 11.0198
# Epoch 827/827
#  - 0s - loss: 1.1037 - mean_q: 11.1629
# Epoch 828/828
#  - 0s - loss: 0.8920 - mean_q: 11.6806
# Epoch 829/829
#  - 0s - loss: 0.5687 - mean_q: 11.4269
# Epoch 830/830
#  - 0s - loss: 0.6205 - mean_q: 11.4116
# Epoch 831/831
#  - 0s - loss: 0.7426 - mean_q: 9.8779
# Epoch 832/832
#  - 0s - loss: 0.4536 - mean_q: 11.7487
# Epoch 833/833
#  - 0s - loss: 2.0851 - mean_q: 11.4887
# Epoch 834/834
#  - 0s - loss: 0.5339 - mean_q: 11.1678
# Epoch 835/835
#  - 0s - loss: 0.7001 - mean_q: 10.0265
# Epoch 836/836
#  - 0s - loss: 0.9105 - mean_q: 11.3287
# Epoch 837/837
#  - 0s - loss: 0.7214 - mean_q: 11.0411
# Epoch 838/838
#  - 0s - loss: 0.7429 - mean_q: 12.4516
# Epoch 839/839
#  - 0s - loss: 0.5829 - mean_q: 12.4014
# Epoch 840/840
#  - 0s - loss: 0.4585 - mean_q: 12.0316
# Epoch 841/841
#  - 0s - loss: 1.2059 - mean_q: 11.3542
# Epoch 842/842
#  - 0s - loss: 0.3218 - mean_q: 11.2865
# Epoch 843/843
#  - 0s - loss: 0.6540 - mean_q: 12.5336
# Epoch 844/844
#  - 0s - loss: 0.6593 - mean_q: 11.8388
# Epoch 845/845
#  - 0s - loss: 0.6233 - mean_q: 11.3918
# Epoch 846/846
#  - 0s - loss: 0.2857 - mean_q: 10.6331
# Epoch 847/847
#  - 0s - loss: 1.1323 - mean_q: 10.3520
# Epoch 848/848
#  - 0s - loss: 0.3843 - mean_q: 11.2798
# Epoch 849/849
#  - 0s - loss: 0.3550 - mean_q: 11.4067
# Epoch 850/850
#  - 0s - loss: 0.5447 - mean_q: 11.4925
# Epoch 851/851
#  - 0s - loss: 0.4739 - mean_q: 11.4226
# Epoch 852/852
#  - 0s - loss: 0.5025 - mean_q: 11.2065
# Epoch 853/853
#  - 0s - loss: 0.2443 - mean_q: 11.1464
# Epoch 854/854
#  - 0s - loss: 1.0588 - mean_q: 10.5031
# Epoch 855/855
#  - 0s - loss: 0.2540 - mean_q: 10.0958
# Epoch 856/856
#  - 0s - loss: 0.4093 - mean_q: 10.9288
# Epoch 857/857
#  - 0s - loss: 0.3260 - mean_q: 11.4486
# Epoch 858/858
#  - 0s - loss: 1.0153 - mean_q: 11.8063
# Epoch 859/859
#  - 0s - loss: 1.4736 - mean_q: 10.8347
# Epoch 860/860
#  - 0s - loss: 0.4121 - mean_q: 10.5843
# Epoch 861/861
#  - 0s - loss: 0.6946 - mean_q: 11.3588
# Epoch 862/862
#  - 0s - loss: 0.6583 - mean_q: 10.6373
# Epoch 863/863
#  - 0s - loss: 0.3543 - mean_q: 10.7523
# Epoch 864/864
#  - 0s - loss: 0.2199 - mean_q: 11.4664
# Epoch 865/865
#  - 0s - loss: 0.5001 - mean_q: 11.7921
# Epoch 866/866
#  - 0s - loss: 0.6393 - mean_q: 11.6123
# Epoch 867/867
#  - 0s - loss: 0.7095 - mean_q: 11.5850
# Epoch 868/868
#  - 0s - loss: 0.5719 - mean_q: 10.7083
# Epoch 869/869
#  - 0s - loss: 0.6217 - mean_q: 10.4524
# Epoch 870/870
#  - 0s - loss: 0.3885 - mean_q: 11.1822
# Epoch 871/871
#  - 0s - loss: 0.2822 - mean_q: 11.2745
# Epoch 872/872
#  - 0s - loss: 0.4615 - mean_q: 10.8231
# Epoch 873/873
#  - 0s - loss: 0.3035 - mean_q: 11.1267
# Epoch 874/874
#  - 0s - loss: 0.9589 - mean_q: 10.5295
# Epoch 875/875
#  - 0s - loss: 0.6964 - mean_q: 10.6775
# Epoch 876/876
#  - 0s - loss: 0.4657 - mean_q: 11.2090
# Epoch 877/877
#  - 0s - loss: 0.4230 - mean_q: 11.1276
# Epoch 878/878
#  - 0s - loss: 0.6555 - mean_q: 11.8291
# Epoch 879/879
#  - 0s - loss: 1.1132 - mean_q: 10.2781
# Epoch 880/880
#  - 0s - loss: 0.4738 - mean_q: 11.6333
# Epoch 881/881
#  - 0s - loss: 0.5557 - mean_q: 10.9812
# Epoch 882/882
#  - 0s - loss: 0.6748 - mean_q: 11.3216
# Epoch 883/883
#  - 0s - loss: 0.4562 - mean_q: 11.1621
# Epoch 884/884
#  - 0s - loss: 0.7870 - mean_q: 11.5861
# Epoch 885/885
#  - 0s - loss: 0.8120 - mean_q: 11.9576
# Epoch 886/886
#  - 0s - loss: 0.5433 - mean_q: 10.3045
# Epoch 887/887
#  - 0s - loss: 0.2431 - mean_q: 11.9101
# Epoch 888/888
#  - 0s - loss: 0.2987 - mean_q: 10.1454
# Epoch 889/889
#  - 0s - loss: 0.2549 - mean_q: 10.9250
# Epoch 890/890
#  - 0s - loss: 0.4659 - mean_q: 10.9207
# Epoch 891/891
#  - 0s - loss: 0.8362 - mean_q: 11.1313
# Epoch 892/892
#  - 0s - loss: 0.6968 - mean_q: 10.8834
# Epoch 893/893
#  - 0s - loss: 0.5664 - mean_q: 11.1266
# Epoch 894/894
#  - 0s - loss: 0.1846 - mean_q: 11.6588
# Epoch 895/895
#  - 0s - loss: 0.7022 - mean_q: 11.4250
# Epoch 896/896
#  - 0s - loss: 0.4798 - mean_q: 11.0392
# Epoch 897/897
#  - 0s - loss: 0.6470 - mean_q: 10.3193
# Epoch 898/898
#  - 0s - loss: 0.5321 - mean_q: 10.5884
# Epoch 899/899
#  - 0s - loss: 0.7189 - mean_q: 10.3007
# Epoch 900/900
#  - 0s - loss: 0.5100 - mean_q: 10.6048
# Epoch 901/901
#  - 0s - loss: 0.6784 - mean_q: 10.5523
# Epoch 902/902
#  - 0s - loss: 0.2972 - mean_q: 11.1159
# Epoch 903/903
#  - 0s - loss: 1.0487 - mean_q: 11.1444
# Epoch 904/904
#  - 0s - loss: 0.8067 - mean_q: 12.0675
# Epoch 905/905
#  - 0s - loss: 0.9444 - mean_q: 12.3101
# Epoch 906/906
#  - 0s - loss: 0.9778 - mean_q: 10.2623
# Epoch 907/907
#  - 0s - loss: 0.3388 - mean_q: 12.1659
# Epoch 908/908
#  - 0s - loss: 0.5418 - mean_q: 12.3730
# Epoch 909/909
#  - 0s - loss: 0.4707 - mean_q: 13.1001
# Epoch 910/910
#  - 0s - loss: 0.6075 - mean_q: 12.7016
# Epoch 911/911
#  - 0s - loss: 0.3758 - mean_q: 11.9451
# Epoch 912/912
#  - 0s - loss: 0.8138 - mean_q: 11.6812
# Epoch 913/913
#  - 0s - loss: 0.6644 - mean_q: 12.1036
# Epoch 914/914
#  - 0s - loss: 0.2496 - mean_q: 11.9320
# Epoch 915/915
#  - 0s - loss: 1.3560 - mean_q: 11.6906
# Epoch 916/916
#  - 0s - loss: 0.9920 - mean_q: 11.9368
# Epoch 917/917
#  - 0s - loss: 0.4540 - mean_q: 12.7345
# Epoch 918/918
#  - 0s - loss: 0.9785 - mean_q: 11.2558
# Epoch 919/919
#  - 0s - loss: 0.9189 - mean_q: 12.5893
# Epoch 920/920
#  - 0s - loss: 0.3012 - mean_q: 12.1426
# Epoch 921/921
#  - 0s - loss: 0.6332 - mean_q: 11.1011
# Epoch 922/922
#  - 0s - loss: 1.0926 - mean_q: 12.4613
# Epoch 923/923
#  - 0s - loss: 0.5972 - mean_q: 12.2091
# ...
#  - 0s - loss: 2.3874 - mean_q: 21.9746
# Epoch 2219/2219
#  - 0s - loss: 1.3880 - mean_q: 19.9317
# Epoch 2220/2220
#  - 0s - loss: 2.0314 - mean_q: 20.5311
# Epoch 2221/2221
#  - 0s - loss: 1.0526 - mean_q: 20.1622
# Epoch 2222/2222
#  - 0s - loss: 1.6403 - mean_q: 23.4762
# Epoch 2223/2223
#  - 0s - loss: 1.0657 - mean_q: 20.8135
# Epoch 2224/2224
#  - 0s - loss: 1.7330 - mean_q: 19.3053
# Epoch 2225/2225
#  - 0s - loss: 3.4381 - mean_q: 20.9762
# Epoch 2226/2226
#  - 0s - loss: 1.0647 - mean_q: 22.1755
# Epoch 2227/2227
#  - 0s - loss: 1.1902 - mean_q: 21.6406
# Epoch 2228/2228
#  - 0s - loss: 1.0226 - mean_q: 22.7274
# Epoch 2229/2229
#  - 0s - loss: 1.3297 - mean_q: 21.6467
# Epoch 2230/2230
#  - 0s - loss: 1.2331 - mean_q: 23.2734
# Epoch 2231/2231
#  - 0s - loss: 1.3037 - mean_q: 23.0781
# Epoch 2232/2232
#  - 0s - loss: 0.8653 - mean_q: 20.9849
# Epoch 2233/2233
#  - 0s - loss: 1.4002 - mean_q: 20.4877
# Epoch 2234/2234
#  - 0s - loss: 1.5455 - mean_q: 23.2828
# Epoch 2235/2235
#  - 0s - loss: 1.8647 - mean_q: 20.7914
# Epoch 2236/2236
#  - 0s - loss: 1.6091 - mean_q: 23.3513
# Epoch 2237/2237
#  - 0s - loss: 1.5584 - mean_q: 20.4919
# Epoch 2238/2238
#  - 0s - loss: 2.3405 - mean_q: 20.8913
# Epoch 2239/2239
#  - 0s - loss: 0.9863 - mean_q: 22.3059
# Epoch 2240/2240
#  - 0s - loss: 1.4057 - mean_q: 21.2014
# Epoch 2241/2241
#  - 0s - loss: 1.4693 - mean_q: 21.0486
# Epoch 2242/2242
#  - 0s - loss: 1.1536 - mean_q: 23.1753
# Epoch 2243/2243
#  - 0s - loss: 1.8958 - mean_q: 20.4116
# Epoch 2244/2244
#  - 0s - loss: 3.0058 - mean_q: 21.8742
# Epoch 2245/2245
#  - 0s - loss: 1.2484 - mean_q: 20.5469
# Epoch 2246/2246
#  - 0s - loss: 1.0704 - mean_q: 22.5902
# Epoch 2247/2247
#  - 0s - loss: 1.8357 - mean_q: 23.0592
# Epoch 2248/2248
#  - 0s - loss: 1.7485 - mean_q: 22.2322
# Epoch 2249/2249
#  - 0s - loss: 2.0875 - mean_q: 23.2134
# Epoch 2250/2250
#  - 0s - loss: 1.1655 - mean_q: 21.0785
# Epoch 2251/2251
#  - 0s - loss: 1.3187 - mean_q: 23.7413
# Epoch 2252/2252
#  - 0s - loss: 1.3762 - mean_q: 20.7133
# Epoch 2253/2253
#  - 0s - loss: 1.7348 - mean_q: 23.3702
# Epoch 2254/2254
#  - 0s - loss: 0.9573 - mean_q: 22.5699
# Epoch 2255/2255
#  - 0s - loss: 2.7030 - mean_q: 20.7307
# Epoch 2256/2256
#  - 0s - loss: 1.2857 - mean_q: 21.6991
# Epoch 2257/2257
#  - 0s - loss: 2.0586 - mean_q: 22.3129
# Epoch 2258/2258
#  - 0s - loss: 1.7464 - mean_q: 22.5582
# Epoch 2259/2259
#  - 0s - loss: 2.0050 - mean_q: 20.8472
# Epoch 2260/2260
#  - 0s - loss: 1.7310 - mean_q: 21.4061
# Epoch 2261/2261
#  - 0s - loss: 1.1741 - mean_q: 19.1353
# Epoch 2262/2262
#  - 0s - loss: 1.5256 - mean_q: 22.4782
# Epoch 2263/2263
#  - 0s - loss: 2.0883 - mean_q: 21.9914
# Epoch 2264/2264
#  - 0s - loss: 1.9675 - mean_q: 22.4085
# Epoch 2265/2265
#  - 0s - loss: 2.3956 - mean_q: 21.5759
# Epoch 2266/2266
#  - 0s - loss: 1.3364 - mean_q: 21.9973
# Epoch 2267/2267
#  - 0s - loss: 2.0596 - mean_q: 22.8860
# Epoch 2268/2268
#  - 0s - loss: 1.5370 - mean_q: 21.1130
# Epoch 2269/2269
#  - 0s - loss: 1.7192 - mean_q: 23.5516
# Epoch 2270/2270
#  - 0s - loss: 2.0327 - mean_q: 21.6756
# Epoch 2271/2271
#  - 0s - loss: 1.3090 - mean_q: 21.6461
# Epoch 2272/2272
#  - 0s - loss: 1.6631 - mean_q: 21.1946
# Epoch 2273/2273
#  - 0s - loss: 0.5936 - mean_q: 24.2949
# Epoch 2274/2274
#  - 0s - loss: 2.6546 - mean_q: 22.3386
# Epoch 2275/2275
#  - 0s - loss: 0.8872 - mean_q: 23.0895
# Epoch 2276/2276
#  - 0s - loss: 1.9052 - mean_q: 21.0479
# Epoch 2277/2277
#  - 0s - loss: 1.2103 - mean_q: 23.1109
# Epoch 2278/2278
#  - 0s - loss: 1.2548 - mean_q: 22.4174
# Epoch 2279/2279
#  - 0s - loss: 1.7294 - mean_q: 23.0801
# Epoch 2280/2280
#  - 0s - loss: 0.9938 - mean_q: 24.1448
# Epoch 2281/2281
#  - 0s - loss: 1.4792 - mean_q: 21.6626
# Epoch 2282/2282
#  - 0s - loss: 0.3902 - mean_q: 24.7584
# Epoch 2283/2283
#  - 0s - loss: 1.2237 - mean_q: 22.9346
# Epoch 2284/2284
#  - 0s - loss: 2.0366 - mean_q: 20.4100
# Epoch 2285/2285
#  - 0s - loss: 1.3509 - mean_q: 20.3391
# Epoch 2286/2286
#  - 0s - loss: 1.1519 - mean_q: 23.2775
# Epoch 2287/2287
#  - 0s - loss: 1.5343 - mean_q: 23.2919
# Epoch 2288/2288
#  - 0s - loss: 1.7232 - mean_q: 21.7114
# Epoch 2289/2289
#  - 0s - loss: 1.7266 - mean_q: 22.8651
# Epoch 2290/2290
#  - 0s - loss: 1.3628 - mean_q: 20.7237
# Epoch 2291/2291
#  - 0s - loss: 1.5589 - mean_q: 18.8470
# Epoch 2292/2292
#  - 0s - loss: 1.6183 - mean_q: 22.6182
# Epoch 2293/2293
#  - 0s - loss: 1.4104 - mean_q: 20.9061
# Epoch 2294/2294
#  - 0s - loss: 1.5242 - mean_q: 21.7559
# Epoch 2295/2295
#  - 0s - loss: 2.1604 - mean_q: 21.9522
# Epoch 2296/2296
#  - 0s - loss: 1.8795 - mean_q: 19.6347
# Epoch 2297/2297
#  - 0s - loss: 1.5030 - mean_q: 20.5745
# Epoch 2298/2298
#  - 0s - loss: 0.9565 - mean_q: 22.7513
# Epoch 2299/2299
#  - 0s - loss: 0.8906 - mean_q: 21.5974
# Epoch 2300/2300
#  - 0s - loss: 0.4973 - mean_q: 24.9199
# Epoch 2301/2301
#  - 0s - loss: 2.2306 - mean_q: 21.5967
# Epoch 2302/2302
#  - 0s - loss: 1.5770 - mean_q: 21.4844
# Epoch 2303/2303
#  - 0s - loss: 1.1053 - mean_q: 23.0375
# Epoch 2304/2304
#  - 0s - loss: 1.7963 - mean_q: 22.3509
# Epoch 2305/2305
#  - 0s - loss: 3.1540 - mean_q: 23.6436
# Epoch 2306/2306
#  - 0s - loss: 1.5679 - mean_q: 25.3100
# Epoch 2307/2307
#  - 0s - loss: 1.6399 - mean_q: 20.9016
# Epoch 2308/2308
#  - 0s - loss: 0.9653 - mean_q: 23.3113
# Epoch 2309/2309
#  - 0s - loss: 1.2995 - mean_q: 23.2919
# Epoch 2310/2310
#  - 0s - loss: 1.8711 - mean_q: 22.6369
# Epoch 2311/2311
#  - 0s - loss: 2.6240 - mean_q: 23.1131
# Epoch 2312/2312
#  - 0s - loss: 1.7684 - mean_q: 19.0019
# Epoch 2313/2313
#  - 0s - loss: 1.8932 - mean_q: 22.2232
# Epoch 2314/2314
#  - 0s - loss: 0.7874 - mean_q: 24.7872
# Epoch 2315/2315
#  - 0s - loss: 1.9885 - mean_q: 21.1170
# Epoch 2316/2316
#  - 0s - loss: 1.3120 - mean_q: 23.5336
# Epoch 2317/2317
#  - 0s - loss: 1.4991 - mean_q: 21.7067
# Epoch 2318/2318
#  - 0s - loss: 1.5230 - mean_q: 20.9408
# Epoch 2319/2319
#  - 0s - loss: 1.8295 - mean_q: 22.5821
# Epoch 2320/2320
#  - 0s - loss: 1.3019 - mean_q: 20.6795
# Epoch 2321/2321
#  - 0s - loss: 1.8711 - mean_q: 19.9117
# Epoch 2322/2322
#  - 0s - loss: 1.7025 - mean_q: 21.1571
# Epoch 2323/2323
#  - 0s - loss: 0.8632 - mean_q: 22.2668
# Epoch 2324/2324
#  - 0s - loss: 2.7590 - mean_q: 20.4698
# Epoch 2325/2325
#  - 0s - loss: 1.3206 - mean_q: 21.5049
# Epoch 2326/2326
#  - 0s - loss: 2.3493 - mean_q: 19.1339
# Epoch 2327/2327
#  - 0s - loss: 1.3315 - mean_q: 19.5802
# Epoch 2328/2328
#  - 0s - loss: 0.8958 - mean_q: 21.5730
# Epoch 2329/2329
#  - 0s - loss: 1.7044 - mean_q: 19.6989
# Epoch 2330/2330
#  - 0s - loss: 1.3941 - mean_q: 26.9498
# Epoch 2331/2331
#  - 0s - loss: 1.0044 - mean_q: 22.4714
# Epoch 2332/2332
#  - 0s - loss: 1.2861 - mean_q: 21.1222
# Epoch 2333/2333
#  - 0s - loss: 1.5399 - mean_q: 21.2018
# Epoch 2334/2334
#  - 0s - loss: 1.0002 - mean_q: 24.4265
# Epoch 2335/2335
#  - 0s - loss: 1.1248 - mean_q: 21.8471
# Epoch 2336/2336
#  - 0s - loss: 2.1975 - mean_q: 21.6310
# Epoch 2337/2337
#  - 0s - loss: 1.0217 - mean_q: 25.2216
# Epoch 2338/2338
#  - 0s - loss: 1.5981 - mean_q: 23.5340
# Epoch 2339/2339
#  - 0s - loss: 1.2869 - mean_q: 22.5679
# Epoch 2340/2340
#  - 0s - loss: 1.3859 - mean_q: 21.7501
# Epoch 2341/2341
#  - 0s - loss: 1.7644 - mean_q: 26.8280
# Epoch 2342/2342
#  - 0s - loss: 0.9820 - mean_q: 21.9085
# Epoch 2343/2343
#  - 0s - loss: 1.0888 - mean_q: 23.2720
# Epoch 2344/2344
#  - 0s - loss: 2.9947 - mean_q: 20.9904
# Epoch 2345/2345
#  - 0s - loss: 1.7687 - mean_q: 20.2605
# Epoch 2346/2346
#  - 0s - loss: 1.2841 - mean_q: 20.4543
# Epoch 2347/2347
#  - 0s - loss: 3.3540 - mean_q: 22.5399
# Epoch 2348/2348
#  - 0s - loss: 0.9036 - mean_q: 21.6408
# Epoch 2349/2349
#  - 0s - loss: 1.7945 - mean_q: 21.5904
# Epoch 2350/2350
#  - 0s - loss: 1.7190 - mean_q: 23.7516
# Epoch 2351/2351
#  - 0s - loss: 1.4030 - mean_q: 23.5182
# Epoch 2352/2352
#  - 0s - loss: 1.7340 - mean_q: 21.2804
# Epoch 2353/2353
#  - 0s - loss: 1.6048 - mean_q: 21.2110
# Epoch 2354/2354
#  - 0s - loss: 1.5771 - mean_q: 20.6051
# Epoch 2355/2355
#  - 0s - loss: 1.3729 - mean_q: 22.6690
# Epoch 2356/2356
#  - 0s - loss: 2.6737 - mean_q: 22.2812
# Epoch 2357/2357
#  - 0s - loss: 1.1634 - mean_q: 21.7281
# Epoch 2358/2358
#  - 0s - loss: 1.1015 - mean_q: 24.7935
# Epoch 2359/2359
#  - 0s - loss: 1.8233 - mean_q: 19.6988
# Epoch 2360/2360
#  - 0s - loss: 1.7575 - mean_q: 22.8331
# Epoch 2361/2361
#  - 0s - loss: 0.5937 - mean_q: 22.2841
# Epoch 2362/2362
#  - 0s - loss: 0.9554 - mean_q: 22.8718
# Epoch 2363/2363
#  - 0s - loss: 1.3247 - mean_q: 22.8542
# Epoch 2364/2364
#  - 0s - loss: 1.0053 - mean_q: 20.6659
# Epoch 2365/2365
#  - 0s - loss: 1.8481 - mean_q: 22.1783
# Epoch 2366/2366
#  - 0s - loss: 1.1493 - mean_q: 23.5106
# Epoch 2367/2367
#  - 0s - loss: 1.4383 - mean_q: 20.5034
# Epoch 2368/2368
#  - 0s - loss: 2.6450 - mean_q: 20.8425
# Epoch 2369/2369
#  - 0s - loss: 1.4862 - mean_q: 22.0265
# Epoch 2370/2370
#  - 0s - loss: 0.8664 - mean_q: 21.8725
# Epoch 2371/2371
#  - 0s - loss: 1.2837 - mean_q: 21.9358
# Epoch 2372/2372
#  - 0s - loss: 2.2658 - mean_q: 20.9864
# Epoch 2373/2373
#  - 0s - loss: 0.6992 - mean_q: 23.9920
# Epoch 2374/2374
#  - 0s - loss: 0.7380 - mean_q: 24.0285
# Epoch 2375/2375
#  - 0s - loss: 1.3121 - mean_q: 22.7767
# Epoch 2376/2376
#  - 0s - loss: 0.8139 - mean_q: 21.1136
# Epoch 2377/2377
#  - 0s - loss: 1.4331 - mean_q: 24.0474
# Epoch 2378/2378
#  - 0s - loss: 2.6177 - mean_q: 21.1820
# Epoch 2379/2379
#  - 0s - loss: 1.3198 - mean_q: 21.7780
# Epoch 2380/2380
#  - 0s - loss: 2.7002 - mean_q: 22.1246
# Epoch 2381/2381
#  - 0s - loss: 1.2512 - mean_q: 24.7571
# Epoch 2382/2382
#  - 0s - loss: 1.8139 - mean_q: 22.8608
# Epoch 2383/2383
#  - 0s - loss: 1.3558 - mean_q: 23.6966
# Epoch 2384/2384
#  - 0s - loss: 1.0790 - mean_q: 21.1260
# Epoch 2385/2385
#  - 0s - loss: 2.0721 - mean_q: 19.8577
# Epoch 2386/2386
#  - 0s - loss: 1.1038 - mean_q: 24.1139
# Epoch 2387/2387
#  - 0s - loss: 1.9574 - mean_q: 22.1924
# Epoch 2388/2388
#  - 0s - loss: 1.4967 - mean_q: 23.5005
# Epoch 2389/2389
#  - 0s - loss: 1.1741 - mean_q: 24.9828
# Epoch 2390/2390
#  - 0s - loss: 1.7218 - mean_q: 22.4479
# Epoch 2391/2391
#  - 0s - loss: 1.4516 - mean_q: 20.3428
# Epoch 2392/2392
#  - 0s - loss: 0.8277 - mean_q: 19.2534
# Epoch 2393/2393
#  - 0s - loss: 1.1462 - mean_q: 23.2308
# Epoch 2394/2394
#  - 0s - loss: 2.5345 - mean_q: 22.9082
# Epoch 2395/2395
#  - 0s - loss: 2.0612 - mean_q: 23.0892
# Epoch 2396/2396
#  - 0s - loss: 1.2051 - mean_q: 23.7558
# Epoch 2397/2397
#  - 0s - loss: 2.6176 - mean_q: 24.6774
# Epoch 2398/2398
#  - 0s - loss: 1.6396 - mean_q: 23.7376
# Epoch 2399/2399
#  - 0s - loss: 2.9014 - mean_q: 23.3794
# Epoch 2400/2400
#  - 0s - loss: 1.7647 - mean_q: 21.7537
# Epoch 2401/2401
#  - 0s - loss: 1.4495 - mean_q: 21.6779
# Epoch 2402/2402
#  - 0s - loss: 1.3778 - mean_q: 24.5871
# Epoch 2403/2403
#  - 0s - loss: 1.8715 - mean_q: 21.1953
# Epoch 2404/2404
#  - 0s - loss: 1.2100 - mean_q: 20.4832
# Epoch 2405/2405
#  - 0s - loss: 1.7889 - mean_q: 22.8428
# Epoch 2406/2406
#  - 0s - loss: 0.8227 - mean_q: 21.1310
# Epoch 2407/2407
#  - 0s - loss: 1.5615 - mean_q: 22.2776
# Epoch 2408/2408
#  - 0s - loss: 0.9671 - mean_q: 24.3274
# Epoch 2409/2409
#  - 0s - loss: 2.8602 - mean_q: 22.5943
# Epoch 2410/2410
#  - 0s - loss: 1.1926 - mean_q: 26.0209
# Epoch 2411/2411
#  - 0s - loss: 1.1746 - mean_q: 23.4115
# Epoch 2412/2412
#  - 0s - loss: 1.6295 - mean_q: 22.3844
# Epoch 2413/2413
#  - 0s - loss: 1.0277 - mean_q: 24.1980
# Epoch 2414/2414
#  - 0s - loss: 1.4692 - mean_q: 24.3293
# Epoch 2415/2415
#  - 0s - loss: 2.3560 - mean_q: 21.9833
# Epoch 2416/2416
#  - 0s - loss: 2.4618 - mean_q: 22.7528
# Epoch 2417/2417
#  - 0s - loss: 1.3220 - mean_q: 25.0382
# Epoch 2418/2418
#  - 0s - loss: 1.5787 - mean_q: 21.8847
# Epoch 2419/2419
#  - 0s - loss: 1.4309 - mean_q: 23.1438
# Epoch 2420/2420
#  - 0s - loss: 1.7485 - mean_q: 23.2005
# Epoch 2421/2421
#  - 0s - loss: 2.1430 - mean_q: 19.7226
# Epoch 2422/2422
#  - 0s - loss: 1.0536 - mean_q: 24.4331
# Epoch 2423/2423
#  - 0s - loss: 2.1313 - mean_q: 22.2987
# Epoch 2424/2424
#  - 0s - loss: 2.4069 - mean_q: 19.3615
# Epoch 2425/2425
#  - 0s - loss: 2.4662 - mean_q: 21.5032
# Epoch 2426/2426
#  - 0s - loss: 1.4615 - mean_q: 21.6836
# Epoch 2427/2427
#  - 0s - loss: 1.0731 - mean_q: 22.7778
# Epoch 2428/2428
#  - 0s - loss: 1.3171 - mean_q: 22.2114
# Epoch 2429/2429
#  - 0s - loss: 1.8485 - mean_q: 23.4549
# Epoch 2430/2430
#  - 0s - loss: 1.5311 - mean_q: 24.2036
# Epoch 2431/2431
#  - 0s - loss: 0.9528 - mean_q: 23.0922
# Epoch 2432/2432
#  - 0s - loss: 2.1201 - mean_q: 22.3282
# Epoch 2433/2433
#  - 0s - loss: 1.5316 - mean_q: 21.6345
# Epoch 2434/2434
#  - 0s - loss: 1.3951 - mean_q: 20.7717
# Epoch 2435/2435
#  - 0s - loss: 1.6743 - mean_q: 22.6291
# Epoch 2436/2436
#  - 0s - loss: 3.4522 - mean_q: 19.8969
# Epoch 2437/2437
#  - 0s - loss: 1.1148 - mean_q: 23.9867
# Epoch 2438/2438
#  - 0s - loss: 1.9078 - mean_q: 22.1104
# Epoch 2439/2439
#  - 0s - loss: 1.1751 - mean_q: 23.4567
# Epoch 2440/2440
#  - 0s - loss: 1.7946 - mean_q: 21.1248
# Epoch 2441/2441
#  - 0s - loss: 1.9728 - mean_q: 21.7825
# Epoch 2442/2442
#  - 0s - loss: 0.9145 - mean_q: 25.0444
# Epoch 2443/2443
#  - 0s - loss: 1.4111 - mean_q: 23.1776
# Epoch 2444/2444
#  - 0s - loss: 1.8540 - mean_q: 25.3964
# Epoch 2445/2445
#  - 0s - loss: 1.4771 - mean_q: 22.3368
# Epoch 2446/2446
#  - 0s - loss: 1.9518 - mean_q: 22.9464
# Epoch 2447/2447
#  - 0s - loss: 2.3611 - mean_q: 24.0082
# Epoch 2448/2448
#  - 0s - loss: 1.8114 - mean_q: 19.9763
# Epoch 2449/2449
#  - 0s - loss: 2.2717 - mean_q: 22.9023
# Epoch 2450/2450
#  - 0s - loss: 1.5170 - mean_q: 22.6702
# Epoch 2451/2451
#  - 0s - loss: 2.3981 - mean_q: 20.6461
# Epoch 2452/2452
#  - 0s - loss: 2.0198 - mean_q: 22.2923
# Epoch 2453/2453
#  - 0s - loss: 1.3796 - mean_q: 21.0649
# Epoch 2454/2454
#  - 0s - loss: 1.0085 - mean_q: 21.2186
# Epoch 2455/2455
#  - 0s - loss: 1.7172 - mean_q: 24.9427
# Epoch 2456/2456
#  - 0s - loss: 2.1778 - mean_q: 22.6214
# Epoch 2457/2457
#  - 0s - loss: 1.4431 - mean_q: 21.3612
# Epoch 2458/2458
#  - 0s - loss: 1.8260 - mean_q: 19.7340
# Epoch 2459/2459
#  - 0s - loss: 2.3933 - mean_q: 21.6041
# Epoch 2460/2460
#  - 0s - loss: 0.5761 - mean_q: 26.7226
# Epoch 2461/2461
#  - 0s - loss: 1.1981 - mean_q: 21.0806
# Epoch 2462/2462
#  - 0s - loss: 1.9371 - mean_q: 20.7490
# Epoch 2463/2463
#  - 0s - loss: 1.4840 - mean_q: 24.3271
# Epoch 2464/2464
#  - 0s - loss: 1.2307 - mean_q: 23.8215
# Epoch 2465/2465
#  - 0s - loss: 2.9444 - mean_q: 21.5643
# Epoch 2466/2466
#  - 0s - loss: 1.2057 - mean_q: 21.8440
# Epoch 2467/2467
#  - 0s - loss: 1.7308 - mean_q: 21.9865
# Epoch 2468/2468
#  - 0s - loss: 1.1815 - mean_q: 23.6353
# Epoch 2469/2469
#  - 0s - loss: 2.3180 - mean_q: 20.2190
# Epoch 2470/2470
#  - 0s - loss: 1.5410 - mean_q: 20.8955
# Epoch 2471/2471
#  - 0s - loss: 1.5141 - mean_q: 21.8906
# Epoch 2472/2472
#  - 0s - loss: 1.2428 - mean_q: 23.1696
# Epoch 2473/2473
#  - 0s - loss: 1.5503 - mean_q: 24.0469
# Epoch 2474/2474
#  - 0s - loss: 1.6626 - mean_q: 21.8357
# Epoch 2475/2475
#  - 0s - loss: 1.2493 - mean_q: 20.5391
# Epoch 2476/2476
#  - 0s - loss: 1.3820 - mean_q: 22.2769
# Epoch 2477/2477
#  - 0s - loss: 1.0353 - mean_q: 26.3447
# Epoch 2478/2478
#  - 0s - loss: 1.6236 - mean_q: 23.9727
# Epoch 2479/2479
#  - 0s - loss: 2.6684 - mean_q: 22.4628
# Epoch 2480/2480
#  - 0s - loss: 0.7211 - mean_q: 23.7939
# Epoch 2481/2481
#  - 0s - loss: 1.0988 - mean_q: 23.7285
# Epoch 2482/2482
#  - 0s - loss: 2.6431 - mean_q: 20.1760
# Epoch 2483/2483
#  - 0s - loss: 0.6692 - mean_q: 24.0702
# Epoch 2484/2484
#  - 0s - loss: 1.8483 - mean_q: 22.1196
# Epoch 2485/2485
#  - 0s - loss: 2.1971 - mean_q: 23.3625
# Epoch 2486/2486
#  - 0s - loss: 2.0421 - mean_q: 24.6442
# Epoch 2487/2487
#  - 0s - loss: 0.9256 - mean_q: 22.7101
# Epoch 2488/2488
#  - 0s - loss: 0.7432 - mean_q: 22.6118
# Epoch 2489/2489
#  - 0s - loss: 0.9323 - mean_q: 20.4704
# Epoch 2490/2490
#  - 0s - loss: 2.1679 - mean_q: 21.5219
# Epoch 2491/2491
#  - 0s - loss: 1.7313 - mean_q: 24.1874
# Epoch 2492/2492
#  - 0s - loss: 2.3668 - mean_q: 21.1856
# Epoch 2493/2493
#  - 0s - loss: 1.5416 - mean_q: 25.2080
# Epoch 2494/2494
#  - 0s - loss: 1.1512 - mean_q: 22.3982
# Epoch 2495/2495
#  - 0s - loss: 1.6049 - mean_q: 21.9124
# Epoch 2496/2496
#  - 0s - loss: 1.0500 - mean_q: 22.8520
# Epoch 2497/2497
#  - 0s - loss: 2.1839 - mean_q: 23.2768
# Epoch 2498/2498
#  - 0s - loss: 1.6920 - mean_q: 23.0661
# Epoch 2499/2499
#  - 0s - loss: 1.0389 - mean_q: 21.4316
# Epoch 2500/2500
#  - 0s - loss: 2.7478 - mean_q: 21.4852
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-5109fa85b079> in <module>
#     123         if step % save_steps == 0:
#     124             online_network.save_weights(os.path.join(weights_folder, 'weights_{}.h5f'.format(step)))
# --> 125             gc.collect()  # also clean the garbage
#     126
#     127
#
# KeyboardInterrupt:

# %%
best_actions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d34a21aabf70> in <module>
# ----> 1 best_actions
#
# NameError: name 'best_actions' is not defined

# %%
import numpy as np
import random
import time
import os
import gc

from collections import deque
from mini_pacman import PacmanGame, test

from keras.models import Sequential, clone_model
from keras.layers import Dense, Flatten, Conv2D, InputLayer, Dropout, BatchNormalization
from keras.callbacks import CSVLogger, TensorBoard
from keras.optimizers import Adam
import keras.backend as K

from keras.models import load_model

def get_state(obs):
    v = []
    x,y = obs['player']
    v.append(x)
    v.append(y)
    for x, y in obs['monsters']:
        v.append(x)
        v.append(y)
    for x, y in obs['diamonds']:
        v.append(x)
        v.append(y)
    for x, y in obs['walls']:
        v.append(x)
        v.append(y)
    return v

def create_dqn_model(input_shape, nb_actions, dense_layers, dense_units):
    model = Sequential()
    model.add(InputLayer(input_shape=input_shape))
    for i in range(dense_layers):
        model.add(Dense(units=dense_units, activation='relu'))
        #model.add(BatchNormalization())                                                                                                                                                                                                                                        
        #model.add(Dropout(0.2))                                                                                                                                                                                                                                                
    model.add(Dense(nb_actions, activation='linear'))
    return model

def epsilon_greedy(q_values, epsilon, n_outputs):
    if random.random() < epsilon:
        return random.randrange(1, n_outputs, 1)  # random action                                                                                                                                                                                                               
    else:
        return 1+np.argmax(q_values)          # q-optimal action                                                                                                                                                                                                                  


input_shape = (32,) #obs.shape                                                                                                                                                                                                                                                  
nb_actions = 9 #env.action_space.n  # 9                                                                                                                                                                                                                                         
dense_layers = 5
dense_units = 256

dqn_model = create_dqn_model(input_shape, nb_actions, dense_layers, dense_units)

#dqn_model = load_model('dqn_model.h5', compile=False)                                                                                                                                                                                                                          
dqn_model.load_weights('MiniPacman_DQN/weights/weights_5000.h5f')

def dqn_strategy(obs):
    state = get_state(obs)
    q_values = dqn_model.predict(np.array([state]))[0]
    eps=0.05
    action = epsilon_greedy(q_values, eps, nb_actions)
    return action

test(strategy=dqn_strategy, log_file='test_pacman_log.json')
# Out:
# Your average score is 45.754, median is 18.0, saved log to 'test_pacman_log.json'. Do not forget to upload it for submission!
# 18.0
